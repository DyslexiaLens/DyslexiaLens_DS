# %% [markdown]
# # 🧠 DyslexiaLens — Data Science Notebook
# ## Persiapan Dataset & Preprocessing
#
# **Tema Capstone:** Accessible & Adaptive Learning
# **Peran:** Data Scientist
# **Dataset:** Gambo — Dyslexia Handwriting Dataset (Kaggle)
#
# ---
#
# ### Deskripsi Singkat
# Notebook ini mencakup seluruh proses persiapan data (*Data Wrangling*) untuk proyek **DyslexiaLens**, sebuah sistem *early screening* disleksia berbasis analisis citra tulisan tangan.
#
# Sistem ini **bukan alat diagnosis medis**, melainkan alat bantu skrining awal yang memberikan indikasi dini kepada orang tua dan pendidik sebelum pemeriksaan lebih lanjut oleh profesional.
#
# ---
#
# ### Alur Notebook
# | Tahap | Deskripsi | Sifat |
# |---|---|---|
# | **Tahap 1** | Assessing Data — Evaluasi kualitas & struktur dataset, audit distribusi dan anomali | Wajib |
# | **Tahap 2** | Physical Renaming — Normalisasi skala nama file fisik ke skala 1–6 | Opsional |
# | **Tahap 3** | Cleaning Data & CSV Generation — Filter data kotor, buat master CSV | Wajib |
# | **Tahap 4** | EDA & Visualisasi Data — Analisis distribusi, imbalance, dan pola visual | Wajib |
# | **Tahap 5** | Data Augmentation — Menyeimbangkan distribusi severity score via rotasi & scaling | Wajib |

# %% [markdown]
# ## 📌 Pertanyaan Bisnis
#
# Notebook ini dirancang untuk menjawab dua pertanyaan bisnis utama yang terukur:
#
# **1. Dapatkah pola goresan tulisan tangan digunakan sebagai indikator awal disleksia?**
# > Hipotesis: Tulisan dari penderita disleksia memiliki pola goresan yang secara visual dapat dibedakan dari tulisan normal — baik melalui pembalikan arah huruf (*Reversal*) maupun koreksi berulang yang meninggalkan bekas coretan (*Corrected*).
#
# **2. Seberapa parah tingkat gejala disleksia berdasarkan keparahan coretan (Severity Score 0–6)?**
# > Hipotesis: Tingkat keparahan goresan dapat dikuantifikasi secara bertingkat, di mana skor lebih tinggi merepresentasikan distorsi tulisan yang lebih ekstrem dan lebih kuat mengindikasikan gejala disleksia.
#
# ---
#
# ### Definisi Variabel Target
#
# | Variabel | Tipe | Nilai | Keterangan |
# |---|---|---|---|
# | `target_class` | Integer | `0` = Normal, `1` = Disleksia | Label biner untuk klasifikasi utama |
# | `severity_score` | Integer | `0` = Sehat, `1`–`6` = Ringan hingga Parah | Skor keparahan gejala disleksia |
# | `folder_category` | String | `Normal`, `Corrected`, `Reversal` | Kategori kelas asal dari dataset |
#
# > **⚠️ Catatan Anti Data Leakage:** Variabel `severity_score` dan `folder_category` **tidak boleh dimasukkan sebagai fitur input model** karena merupakan turunan langsung dari label. Hanya `image_path` yang menjadi input — dan `target_class` yang menjadi output target utama.

# %% [markdown]
# ## 📦 Sumber Dataset & Referensi Ilmiah
#
# ### Identitas Dataset
# | Atribut | Detail |
# |---|---|
# | **Nama** | Dyslexia Handwriting Dataset (Gambo) |
# | **Sumber** | Kaggle — Dataset Publik |
# | **Link** | https://www.kaggle.com/datasets/drizasazanitaisa/dyslexia-handwriting-dataset |
# | **Total Gambar** | 208.372 file `.png` |
# | **Format** | Grayscale, resolusi 28×28 piksel |
# | **Kelas** | `Normal`, `Corrected`, `Reversal` |
#
# ### Cara Mendapatkan Dataset
# Dataset tidak disertakan di dalam repositori Git (di-*gitignore*) karena ukurannya yang besar.
# Untuk menjalankan notebook ini secara **lokal**, lakukan langkah berikut:
# 1. Unduh dataset dari link Kaggle di atas.
# 2. Ekstrak dan letakkan folder `Gambo/` di direktori yang sama dengan file notebook ini.
# 3. Pastikan struktur folder: `Gambo/Train/` dan `Gambo/Test/` sudah tersedia.
#
# Untuk menjalankan di **Google Colab**:
# 1. Upload folder `Gambo/` ke Google Drive Anda.
# 2. Mount Google Drive di Colab, lalu ubah variabel `root_dir` di setiap cell menjadi path Drive Anda (misal: `'/content/drive/MyDrive/Gambo'`).
#
# ### Referensi Ilmiah
# Dataset ini dipublikasikan dan digunakan dalam penelitian berikut:
#
# 1. M. S. A. B. Rosli, I. S. Isa, S. A. Ramlan, S. N. Sulaiman and M. I. F. Maruzuki, *"Development of CNN Transfer Learning for Dyslexia Handwriting Recognition"*, 2021 11th IEEE International Conference on Control System, Computing and Engineering (ICCSCE), 2021, pp. 194-199, doi: 10.1109/ICCSCE52189.2021.9530971.
#
# 2. N. S. L. Seman, I. S. Isa, S. A. Ramlan, W. Li-Chih and M. I. F. Maruzuki, *"Classification of Handwriting Impairment Using CNN for Potential Dyslexia Symptom"*, 2021 11th IEEE International Conference on Control System, Computing and Engineering (ICCSCE), 2021, pp. 188-193, doi: 10.1109/ICCSCE52189.2021.9530989.
#
# 3. Isa, Iza Sazanita. *CNN Comparisons Models On Dyslexia Handwriting Classification*. Universiti Teknologi MARA Cawangan Pulau Pinang, 2021.
#
# 4. Isa, I. S., Rahimi, W. N. S., Ramlan, S. A., & Sulaiman, S. N. (2019). *Automated detection of dyslexia symptom based on handwriting image for primary school children*. Procedia Computer Science, 163, 440-449.

# %% [markdown]
# ---
# # Tahap 1: Assessing Data — Evaluasi Kualitas & Struktur Dataset
#
# Sebelum melakukan pembersihan data, kita perlu memahami **apa yang ada di dalam dataset** secara menyeluruh. Tahap *Assessing Data* ini meliputi:
# 1. Mengecek distribusi jumlah file per kelas dan per split
# 2. Memvalidasi konsistensi format (ekstensi, resolusi, mode warna)
# 3. Mengaudit penamaan file untuk menemukan anomali label
#
# ---
#
# ### Temuan Utama (Hasil Audit Manual + Algoritmik)
#
# **✅ Temuan 1 — Sistem Severity Score (Kunci)**
# Folder numerik `1, 4, 5, 6, 7, 8, 9` di dalam kelas `Corrected` dan `Reversal` **bukan** merepresentasikan karakter angka yang ditulis, melainkan **Tingkat Keparahan Goresan (Severity Score)**. Inspeksi visual membuktikan hampir seluruh abjad tersebar merata di tiap folder — tidak ada konsentrasi karakter tertentu. Ini berarti dataset **tidak mengalami Data Leakage** dan model akan dipaksa belajar pola goresan, bukan menghafal karakter.
#
# | Skor Asli (Periset) | Kondisi Visual | Keparahan Nyata | Skor AI (Setelah Normalisasi) |
# |---|---|---|---|
# | `1` | Goresan hancur lebur, hampir tidak terbaca | **Paling Parah** | `6` |
# | `4` | Banyak timpa-menimpa, kerangka huruf samar | Parah | `6` (digabung) |
# | `5`–`8` | Koreksi tampak, huruf masih bisa ditebak | Menengah | `5` → `2` |
# | `9` | Goresan ringan, huruf aslinya mudah dikenali | **Paling Ringan** | `1` |
#
# > ⚠️ Skala asli bersifat **terbalik** — `1` = Parah (bukan Ringan), `9` = Ringan (bukan Parah). Jika langsung digunakan sebagai label angka, model AI akan menganggap tulisan paling parah (skor 1) justru paling dekat dengan Normal (skor 0). Ini dikoreksi melalui *Dictionary Mapping* di Tahap 2 & Tahap 3.
#
# ---
#
# **⚠️ Temuan 2 — Kontaminasi Label (Label Noise) di Kelas Non-Normal**
# Ditemukan file bernama `NormalXXXX.png` yang terselip di dalam folder `Corrected` dan `Reversal`. Secara visual, konten gambar-gambar tersebut adalah goresan cacat — bukan tulisan tangan normal yang bersih. Ini adalah *Label Noise* yang terjadi kemungkinan akibat *script rename otomatis* tanpa verifikasi visual dari pihak pembuat dataset asli.
#
# ---
#
# **⚠️ Temuan 3 — Anomali Visual di Kelas Normal Asli**
# Melalui inspeksi visual manual pada sampel gambar di dalam kelas `Normal`, ditemukan bahwa **tidak semua gambar di kelas Normal benar-benar bersih**. Sejumlah sampel menampilkan goresan koreksi atau pola yang secara visual menyerupai karakteristik `Corrected`, meskipun secara nama file dan letak folder dikategorikan sebagai `Normal`.
#
# Ini memperkuat indikasi adanya **Kontaminasi Label Dua Arah** dari dataset asli:
# - File bergoresan cacat masuk ke folder Normal (`NormalXXXX.png` tersesat)
# - File bertulisan normal yang secara visual wajar, namun labelnya terkontaminasi oleh goresan lingkungan sekitar saat pengambilan data
#
# > 📌 Temuan ini menjadi dasar keputusan untuk **tidak semata-mata mengandalkan nama folder** sebagai label tunggal, dan mendukung penggunaan `master_dataset_dyslexia.csv` dengan filter eksplisit sebagai sumber kebenaran (*ground truth*) untuk proses training.

# %% [markdown]
# ### 1A. Statistik Distribusi Dataset

# %%
import os
from pathlib import Path
from collections import defaultdict

root_dir = r'Dataset/Gambo'

stats = defaultdict(lambda: defaultdict(int))
total = 0
noise_count = 0
non_png_count = 0

for root, dirs, files in os.walk(root_dir):
    for file in files:
        ext = os.path.splitext(file)[1].lower()
        if ext != '.png':
            non_png_count += 1
            continue
        parts = Path(root).parts
        try:
            split_type = parts[-2]
            category  = parts[-1]
        except:
            continue
        stats[split_type][category] += 1
        total += 1
        if 'Normal' in file and category != 'Normal':
            noise_count += 1

print('=' * 55)
print('     STATISTIK DISTRIBUSI DATASET GAMBO')
print('=' * 55)
for split, categories in sorted(stats.items()):
    subtotal = sum(categories.values())
    print(f'\n📁 {split} ({subtotal:,} gambar)')
    for cat, count in sorted(categories.items()):
        print(f'   └── {cat:12s}: {count:>7,} gambar')

print(f'\n{"-" * 55}')
print(f'  Total file .png          : {total:,}')
print(f'  File non-.png ditemukan  : {non_png_count:,}  (diabaikan)')
print(f'  File Noise terdeteksi    : {noise_count:,}  (akan di-drop di Tahap 3)')
print(f'  Estimasi data bersih     : {total - noise_count:,}')
print('=' * 55)
# Out:
# =======================================================
#      STATISTIK DISTRIBUSI DATASET GAMBO
# =======================================================
#
# 📁 Test (56,723 gambar)
#    └── Corrected   :  19,284 gambar
#    └── Normal      :  19,557 gambar
#    └── Reversal    :  17,882 gambar
#
# 📁 Train (151,649 gambar)
#    └── Corrected   :  65,534 gambar
#    └── Normal      :  39,334 gambar
#    └── Reversal    :  46,781 gambar
#
# -------------------------------------------------------
#   Total file .png          : 208,372
#   File non-.png ditemukan  : 0  (diabaikan)
#   File Noise terdeteksi    : 628  (akan di-drop di Tahap 3)
#   Estimasi data bersih     : 207,744
# =======================================================

# %% [markdown]
# ### 1B. Verifikasi Integritas File, Resolusi & Format Warna
#
# Kode berikut melakukan *sampling* acak dari setiap kelas untuk memverifikasi:
# - Apakah file dapat dibuka (tidak corrupt)
# - Konsistensi resolusi (ukuran piksel)
# - Konsistensi format warna (*color mode*)

# %%
import os
import random
from pathlib import Path
from collections import Counter, defaultdict
from PIL import Image

root_dir = r'Dataset/Gambo'
SAMPLE_PER_CLASS = 500

class_files = defaultdict(list)
for root, dirs, files in os.walk(root_dir):
    for file in files:
        if file.endswith('.png'):
            parts = Path(root).parts
            try:
                category = parts[-1]
            except:
                continue
            class_files[category].append(os.path.join(root, file))

print('=' * 55)
print('  VERIFIKASI INTEGRITAS, RESOLUSI & FORMAT WARNA')
print('=' * 55)

for category, paths in sorted(class_files.items()):
    sample = random.sample(paths, min(SAMPLE_PER_CLASS, len(paths)))
    resolutions = Counter()
    modes = Counter()
    corrupt = 0
    for path in sample:
        try:
            with Image.open(path) as img:
                resolutions[img.size] += 1
                modes[img.mode] += 1
        except Exception:
            corrupt += 1

    print(f'\n📂 Kelas: {category} (sample {len(sample)} dari {len(paths):,} file)')
    print(f'   File corrupt        : {corrupt}')
    print(f'   Resolusi ditemukan  : {dict(resolutions.most_common(3))}')
    print(f'   Format warna        : {dict(modes)}')

print('\n' + '=' * 55)
print('  Verifikasi selesai.')
print('=' * 55)
# Out:
# =======================================================
#   VERIFIKASI INTEGRITAS, RESOLUSI & FORMAT WARNA
# =======================================================
#
# 📂 Kelas: Corrected (sample 500 dari 84,818 file)
#    File corrupt        : 0
#    Resolusi ditemukan  : {(30, 30): 205, (29, 29): 192, (31, 31): 53}
#    Format warna        : {'L': 471, 'RGB': 29}
#
# 📂 Kelas: Normal (sample 500 dari 58,891 file)
#    File corrupt        : 0
#    Resolusi ditemukan  : {(28, 28): 500}
#    Format warna        : {'L': 316, 'RGB': 184}
#
# 📂 Kelas: Reversal (sample 500 dari 64,663 file)
#    File corrupt        : 0
#    Resolusi ditemukan  : {(29, 29): 293, (28, 28): 207}
#    Format warna        : {'L': 289, '1': 141, 'RGB': 70}
#
# =======================================================
#   Verifikasi selesai.
# =======================================================

# %% [markdown]
# ### Kesimpulan Assessing
#
# | Aspek | Status | Keterangan |
# |---|---|---|
# | Struktur folder | ✅ | `Train/Test → Normal/Corrected/Reversal` — hierarki bersih |
# | Format file | ✅ | 100% berformat `.png`, nol file non-PNG |
# | Integritas file | ✅ | Nol file corrupt dari hasil sampling |
# | Resolusi gambar | ✅ | 28×28 piksel (identik dengan format MNIST/EMNIST) |
# | Format warna | ✅ | Grayscale (`L`) atau Binary (`1`) — tidak ada RGB |
# | Distribusi kelas | ⚠️ | Corrected lebih dominan — perlu pantau *class imbalance* |
# | Severity Score | ✅ | Folder 1–9 = derajat keparahan (bukan karakter), skala terbalik |
# | Label Noise (kelas non-Normal) | ⚠️ | File `NormalXXXX.png` terselip — di-*drop* di Tahap 3 |
# | Anomali visual kelas Normal | ⚠️ | Sebagian sampel Normal mengandung goresan tidak wajar — tercatat sebagai risiko residual |

# %% [markdown]
# ---
# # Tahap 2: Preprocessing Tambahan (Physical Renaming) — Opsional
# Kode opsional ini secara fisik mengganti nama file di local disk Anda agar skala keparahannya berurutan menjadi skala **1 sampai 6** (1 = Paling Ringan, 6 = Paling Parah) menggunakan *Dictionary Mapping*:
#
# | Skor Asli | → | Skor Baru | Keterangan |
# |---|---|---|---|
# | `9` | → | `1` | Paling Ringan |
# | `8` | → | `2` | |
# | `7` | → | `3` | |
# | `6` | → | `4` | |
# | `5` | → | `5` | |
# | `4` | → | `6` | Corrected Paling Parah |
# | `1` | → | `6` | Reversal (digabung ke puncak) |
#
# > ⚠️ **Jalankan sel ini hanya SEKALI.** Menjalankannya dua kali pada dataset yang sudah di-rename akan menyebabkan skala bergeser dan data menjadi kacau.
# >
# > ℹ️ **Opsional:** Jika Anda melewati Tahap 2, kode Tahap 3 tetap berfungsi karena `get_score` sudah dirancang untuk menangani **kedua kondisi** (skala asli dan skala setelah di-rename).

# %%
import os
import time

root_dir = r'Dataset/Gambo'

print("Mempersiapkan penggantian nama (Physical Renaming) skala 1-6...")

score_map = {
    9: 1, 8: 2, 7: 3, 6: 4, 5: 5,
    4: 6, # Asli 4 (Corrected Paling Parah) -> Jadi Skor AI 6
    1: 6  # Asli 1 (Reversal) -> Sama-sama disatukan di puncak Skor AI 6
}

to_rename = []
for root, dirs, files in os.walk(root_dir):
    if not ('Corrected' in root or 'Reversal' in root):
        continue
    for file in files:
        if file.endswith('.png'):
            prefix, separator = None, None
            if '_' in file:
                head = file.split('_')[0]
                if head.isdigit() and int(head) in score_map:
                    prefix, separator = int(head), '_'
            elif '-' in file:
                head = file.split('-')[0]
                if head.isdigit() and int(head) in score_map:
                    prefix, separator = int(head), '-'
            if prefix is not None:
                new_prefix = score_map[prefix]
                sisa_nama = file.split(separator, 1)[1]
                new_name = f"{new_prefix}{separator}{sisa_nama}"
                to_rename.append((os.path.join(root, file), os.path.join(root, new_name)))

print(f"Total file yang akan dimapping ulang namanya: {len(to_rename)} file.")

temp_rename = []
for old, new in to_rename:
    temp_path = new + ".TEMP"
    os.rename(old, temp_path)
    temp_rename.append((temp_path, new))

for temp, final_new in temp_rename:
    berhasil = False
    for _ in range(10):
        try:
            os.replace(temp, final_new)
            berhasil = True
            break
        except PermissionError:
            time.sleep(0.1)
    if not berhasil:
        print(f"Gagal: {final_new}")

print("Selesai! Seluruh nama fisik file berhasil dipetakan ke skala konsisten (1 Ringan -> 6 Parah)!")
# Out:
# Mempersiapkan penggantian nama (Physical Renaming) skala 1-6...
# Total file yang akan dimapping ulang namanya: 121835 file.
# Selesai! Seluruh nama fisik file berhasil dipetakan ke skala konsisten (1 Ringan -> 6 Parah)!

# %% [markdown]
# ---
# # Tahap 3: Cleaning Data & Pembuatan Master CSV
#
# Kode ini melakukan **Logical Cleaning** — memfilter semua file kotor (*Label Noise*) langsung dari tabel Pandas **tanpa menghapus file fisik aslinya**, lalu menyimpan daftar data bersih ke `master_dataset_dyslexia.csv`.
#
# ### Filter Pembersihan Eksplisit
# Selain filter skor, pipeline ini membuang file-file **sampah / duplikat / anomali**:
#
# | Pola File | Contoh | Alasan Dibuang |
# |---|---|---|
# | Duplikat Windows `(1)` | `Normal1305 (11).png`, `Reversal (1).png` | File hasil *copy-paste* berulang di Windows (menghindari duplikasi data) |
# | Placeholder Murni | `Normal.png`, `Reversal.png` | Bukan sampel tulisan tangan yang sesungguhnya |
# | Temporary / Glitch | `e-491.qNcy3.png` | File arsip rusak / ekstensi ganda dari *download* terputus |
# | Abjad di Disleksia | `A.png`, `b.png` | File abjad referensi murni, bukan tulisan pasien |
# | Label Noise (Normal) | `Normal123.png` di Corrected | File Normal yang terselip ke folder disleksia |
#
# > **PENTING:** Jalankan sel ini hanya SEKALI setelah Tahap 1 (dan opsional Tahap 2).

# %%
import os
import re
import pandas as pd
from pathlib import Path

root_dir = r'Dataset/Gambo'

SCORE_MAP_ORIGINAL = {1: 6, 4: 6, 5: 5, 6: 4, 7: 3, 8: 2, 9: 1}

# ============================================================
# REGEX FILTER
# ============================================================

RE_DUPLICATE_WIN = re.compile(r'\(\d+\)')  # (1), (2), dst
RE_PLACEHOLDER = re.compile(r'^(Normal|Reversal|Corrected)\.png$', re.IGNORECASE)
RE_GLITCH = re.compile(r'\.qNcy', re.IGNORECASE)
RE_ALPHA_ONLY = re.compile(r'^[A-Za-z]\.png$')

# 🔥 TAMBAHAN BARU
RE_NORMAL_NUMBER = re.compile(r'^Normal\d+', re.IGNORECASE)
RE_REVERSAL_NUMBER = re.compile(r'^Reversal\d+', re.IGNORECASE)
RE_STARTS_WITH_ALPHA = re.compile(r'^[A-Za-z][-_.]')

print('Membaca seluruh direktori...')

data = []
filtered_out = {
    'duplicate': 0,
    'placeholder': 0,
    'glitch': 0,
    'alpha_only': 0,
    'normal_number': 0,
    'reversal_number': 0,
    'starts_alpha': 0
}

for root, dirs, files in os.walk(root_dir):
    for file in files:
        if not file.lower().endswith('.png'):
            continue

        parts = Path(root).parts

        try:
            split_type = parts[-2]     # Train / Test
            category = parts[-1]       # Normal / Corrected / Reversal
        except:
            continue

        # ====================================================
        # FILTER
        # ====================================================

        # 1. Duplikat Windows
        if RE_DUPLICATE_WIN.search(file):
            filtered_out['duplicate'] += 1
            continue

        # 2. Glitch file
        if RE_GLITCH.search(file):
            filtered_out['glitch'] += 1
            continue

        # 3. Placeholder
        if RE_PLACEHOLDER.match(file):
            filtered_out['placeholder'] += 1
            continue

        # 4. Abjad tunggal
        if category in ['Corrected', 'Reversal'] and RE_ALPHA_ONLY.match(file):
            filtered_out['alpha_only'] += 1
            continue

        # 🔥 5. Normal + angka → buang
        if category == 'Normal' and RE_NORMAL_NUMBER.match(file):
            filtered_out['normal_number'] += 1
            continue

        # 🔥 6. Reversal + angka → buang
        if category == 'Reversal' and RE_REVERSAL_NUMBER.match(file):
            filtered_out['reversal_number'] += 1
            continue

        # 🔥 7. Awalan huruf (A-xxx, P-xxx, dll)
        if category in ['Corrected', 'Reversal'] and RE_STARTS_WITH_ALPHA.match(file):
            filtered_out['starts_alpha'] += 1
            continue

        # ====================================================
        # SIMPAN DATA
        # ====================================================

        path_full = os.path.join(root, file)

        data.append({
            'image_path': path_full,
            'file_name': file,
            'split': split_type,
            'folder_category': category
        })

# ============================================================
# DATAFRAME
# ============================================================

df = pd.DataFrame(data)

print(f'\nTotal gambar bersih sementara: {len(df)} file.')

print(f'\n=== File Dibuang (Filter) ===')
print(f'  Duplikat Windows `(X)`       : {filtered_out["duplicate"]}')
print(f'  File Glitch (`.qNcy`)        : {filtered_out["glitch"]}')
print(f'  Placeholder                 : {filtered_out["placeholder"]}')
print(f'  Abjad tunggal               : {filtered_out["alpha_only"]}')
print(f'  Normal + angka              : {filtered_out["normal_number"]}')
print(f'  Reversal + angka            : {filtered_out["reversal_number"]}')
print(f'  Awalan huruf (A-, P-, dll)  : {filtered_out["starts_alpha"]}')
print(f'  TOTAL dibuang               : {sum(filtered_out.values())}\n')

# ============================================================
# SCORING
# ============================================================

def get_score(row):
    filename = row['file_name']
    folder = row['folder_category']

    # mismatch label
    if 'Normal' in filename and folder != 'Normal':
        return 'DROP'

    # Normal
    if folder == 'Normal':
        return 0

    # Corrected / Reversal
    if folder in ['Corrected', 'Reversal']:
        for sep in ['_', '-']:
            if sep in filename:
                prefix = filename.split(sep)[0]

                if prefix.isdigit():
                    val = int(prefix)

                    if 1 <= val <= 6:
                        return val
                    elif val in SCORE_MAP_ORIGINAL:
                        return SCORE_MAP_ORIGINAL[val]
                break

    return 'DROP'

df['severity_score'] = df.apply(get_score, axis=1)

dropped_by_score = len(df[df['severity_score'].astype(str) == 'DROP'])
print(f'File dibuang oleh get_score : {dropped_by_score}')

# ============================================================
# CLEAN FINAL
# ============================================================

df_clean = df[~df['severity_score'].astype(str).str.contains('DROP')].copy()
df_clean['severity_score'] = df_clean['severity_score'].astype(int)

# Binary class
df_clean['target_class'] = df_clean['severity_score'].apply(lambda x: 0 if x == 0 else 1)

# ============================================================
# SAVE
# ============================================================

output_csv = 'master_dataset_dyslexia.csv'
df_clean.to_csv(output_csv, index=False)

print(f'\nSUCCESS! Disimpan ke "{output_csv}" sebanyak {len(df_clean):,} file.')

# Sample
print('\nContoh data:')
print(df_clean.sample(5))
# Out:
# Membaca seluruh direktori...
#
# Total gambar bersih sementara: 161002 file.
#
# === File Dibuang (Filter) ===
#   Duplikat Windows `(X)`       : 20299
#   File Glitch (`.qNcy`)        : 2
#   Placeholder                 : 0
#   Abjad tunggal               : 0
#   Normal + angka              : 3560
#   Reversal + angka            : 512
#   Awalan huruf (A-, P-, dll)  : 22997
#   TOTAL dibuang               : 47370
#
# File dibuang oleh get_score : 577
#
# SUCCESS! Disimpan ke "master_dataset_dyslexia.csv" sebanyak 160,425 file.
#
# Contoh data:
#                                       image_path    file_name  split  \
# 107403     Dataset/Gambo\Train\Normal\C-2203.png   C-2203.png  Train
# 134072  Dataset/Gambo\Train\Reversal\6_14692.png  6_14692.png  Train
# 137774  Dataset/Gambo\Train\Reversal\6_18023.png  6_18023.png  Train
# 132024  Dataset/Gambo\Train\Reversal\6_12849.png  6_12849.png  Train
# 102962     Dataset/Gambo\Train\Normal\A-1309.png   A-1309.png  Train
#
#        folder_category  severity_score  target_class
# 107403          Normal               0             0
# 134072        Reversal               6             1
# 137774        Reversal               6             1
# 132024        Reversal               6             1
# 102962          Normal               0             0

# %%
import os
import pandas as pd

root_dir = r'Dataset/Gambo'
csv_path = 'master_dataset_dyslexia.csv'

# 🔒 MODE AMAN
DRY_RUN = False  # ubah ke False kalau sudah yakin

# ============================================================
# LOAD CSV (file yang VALID)
# ============================================================

df = pd.read_csv(csv_path)

# Normalize path (biar aman)
valid_paths = set(df['image_path'].apply(os.path.normpath))

print(f"Total file valid dari CSV: {len(valid_paths)}")

# ============================================================
# SCAN & DELETE
# ============================================================

deleted = 0
kept = 0

for root, dirs, files in os.walk(root_dir):
    for file in files:
        if not file.lower().endswith('.png'):
            continue

        full_path = os.path.normpath(os.path.join(root, file))

        if full_path not in valid_paths:
            deleted += 1

            if DRY_RUN:
                print(f"[DELETE] {full_path}")
            else:
                try:
                    os.remove(full_path)
                except Exception as e:
                    print(f"[ERROR] {full_path} -> {e}")
        else:
            kept += 1

# ============================================================
# SUMMARY
# ============================================================

print("\n=== SUMMARY ===")
print(f"File dipertahankan : {kept}")
print(f"File dihapus       : {deleted}")
# Out:
# Total file valid dari CSV: 160425
#
# === SUMMARY ===
# File dipertahankan : 160425
# File dihapus       : 47947

# %%
import os
import numpy as np

from PIL import Image

root_dir = r'Dataset/Gambo'

DRY_RUN = False  # False = benar-benar hapus

deleted = 0
processed = 0
errors = 0

print("Scanning gambar background putih...\n")

for root, dirs, files in os.walk(root_dir):

    for file in files:

        if not file.lower().endswith('.png'):
            continue

        path = os.path.join(root, file)

        try:

            img = Image.open(path).convert('L')

            arr = np.array(img)

            mean_pixel = np.mean(arr)

            # dominan terang = background putih
            if mean_pixel > 127:

                deleted += 1

                if DRY_RUN:
                    print(f'[DELETE] {path}')
                else:
                    os.remove(path)

            processed += 1

            if processed % 10000 == 0:
                print(f'Processed: {processed:,}')

        except Exception as e:
            errors += 1
            print(f'[ERROR] {path} -> {e}')

print("\n=== DONE ===")
print(f'Processed : {processed:,}')
print(f'Deleted   : {deleted:,}')
print(f'Errors    : {errors}')
# Out:
# Scanning gambar background putih...
#
# Processed: 10,000
# Processed: 20,000
# Processed: 30,000
# Processed: 40,000
# Processed: 50,000
# Processed: 60,000
# Processed: 70,000
# Processed: 80,000
# Processed: 90,000
# Processed: 100,000
# Processed: 110,000
# Processed: 120,000
# Processed: 130,000
# Processed: 140,000
# Processed: 150,000
# Processed: 160,000
#
# === DONE ===
# Processed : 160,425
# Deleted   : 3,972
# Errors    : 0

# %%
import os
import re
import pandas as pd

from pathlib import Path

# ============================================================
# CONFIG
# ============================================================

root_dir = r'Dataset/Gambo'

output_csv = 'master_dataset_dyslexia.csv'

SCORE_MAP_ORIGINAL = {
    1: 6,
    4: 6,
    5: 5,
    6: 4,
    7: 3,
    8: 2,
    9: 1
}

# ============================================================
# REGEX FILTER
# ============================================================

RE_DUPLICATE_WIN = re.compile(r'\(\d+\)')
RE_PLACEHOLDER = re.compile(
    r'^(Normal|Reversal|Corrected)\.png$',
    re.IGNORECASE
)

RE_GLITCH = re.compile(r'\.qNcy', re.IGNORECASE)

RE_ALPHA_ONLY = re.compile(r'^[A-Za-z]\.png$')

RE_NORMAL_NUMBER = re.compile(r'^Normal\d+', re.IGNORECASE)

RE_REVERSAL_NUMBER = re.compile(r'^Reversal\d+', re.IGNORECASE)

RE_STARTS_WITH_ALPHA = re.compile(r'^[A-Za-z][-_.]')

# ============================================================
# SCAN DATASET
# ============================================================

print('Scanning dataset...\n')

data = []

filtered_out = {
    'duplicate': 0,
    'placeholder': 0,
    'glitch': 0,
    'alpha_only': 0,
    'normal_number': 0,
    'reversal_number': 0,
    'starts_alpha': 0,
    'missing_file': 0
}

processed = 0

for root, dirs, files in os.walk(root_dir):

    for file in files:

        if not file.lower().endswith('.png'):
            continue

        processed += 1

        if processed % 10000 == 0:
            print(f'Processed: {processed:,}')

        parts = Path(root).parts

        try:
            split_type = parts[-2]
            category = parts[-1]
        except:
            continue

        # ====================================================
        # FILTER
        # ====================================================

        if RE_DUPLICATE_WIN.search(file):
            filtered_out['duplicate'] += 1
            continue

        if RE_GLITCH.search(file):
            filtered_out['glitch'] += 1
            continue

        if RE_PLACEHOLDER.match(file):
            filtered_out['placeholder'] += 1
            continue

        if category in ['Corrected', 'Reversal'] and RE_ALPHA_ONLY.match(file):
            filtered_out['alpha_only'] += 1
            continue

        if category == 'Normal' and RE_NORMAL_NUMBER.match(file):
            filtered_out['normal_number'] += 1
            continue

        if category == 'Reversal' and RE_REVERSAL_NUMBER.match(file):
            filtered_out['reversal_number'] += 1
            continue

        if category in ['Corrected', 'Reversal'] and RE_STARTS_WITH_ALPHA.match(file):
            filtered_out['starts_alpha'] += 1
            continue

        # ====================================================
        # VALIDASI FILE
        # ====================================================

        path_full = os.path.normpath(os.path.join(root, file))

        if not os.path.exists(path_full):
            filtered_out['missing_file'] += 1
            continue

        # ====================================================
        # SAVE ROW
        # ====================================================

        data.append({
            'image_path': path_full,
            'file_name': file,
            'split': split_type,
            'folder_category': category
        })

# ============================================================
# DATAFRAME
# ============================================================

df = pd.DataFrame(data)

print(f'\nTotal kandidat bersih: {len(df):,}')

# ============================================================
# LABELING
# ============================================================

def get_score(row):

    filename = row['file_name']
    folder = row['folder_category']

    # mismatch
    if 'Normal' in filename and folder != 'Normal':
        return 'DROP'

    # normal
    if folder == 'Normal':
        return 0

    # corrected/reversal
    if folder in ['Corrected', 'Reversal']:

        for sep in ['_', '-']:

            if sep in filename:

                prefix = filename.split(sep)[0]

                if prefix.isdigit():

                    val = int(prefix)

                    if 1 <= val <= 6:
                        return val

                    elif val in SCORE_MAP_ORIGINAL:
                        return SCORE_MAP_ORIGINAL[val]

                break

    return 'DROP'

# ============================================================
# APPLY SCORE
# ============================================================

df['severity_score'] = df.apply(get_score, axis=1)

dropped_by_score = len(
    df[df['severity_score'].astype(str) == 'DROP']
)

print(f'\nDropped by get_score: {dropped_by_score:,}')

# ============================================================
# CLEAN FINAL
# ============================================================

df_clean = df[
    ~df['severity_score'].astype(str).str.contains('DROP')
].copy()

df_clean['severity_score'] = df_clean['severity_score'].astype(int)

df_clean['target_class'] = df_clean['severity_score'].apply(
    lambda x: 0 if x == 0 else 1
)

# ============================================================
# SAVE CSV
# ============================================================

df_clean.to_csv(output_csv, index=False)

# ============================================================
# SUMMARY
# ============================================================

print('\n=== FILTER SUMMARY ===')

for k, v in filtered_out.items():
    print(f'{k:20s}: {v:,}')

print(f'\nFinal dataset: {len(df_clean):,} rows')

print(f'\nCSV saved:')
print(output_csv)

print('\nContoh data:')
print(df_clean.sample(5))
# Out:
# Scanning dataset...
#
# Processed: 10,000
# Processed: 20,000
# Processed: 30,000
# Processed: 40,000
# Processed: 50,000
# Processed: 60,000
# Processed: 70,000
# Processed: 80,000
# Processed: 90,000
# Processed: 100,000
# Processed: 110,000
# Processed: 120,000
# Processed: 130,000
# Processed: 140,000
# Processed: 150,000
#
# Total kandidat bersih: 156,453
#
# Dropped by get_score: 0
#
# === FILTER SUMMARY ===
# duplicate           : 0
# placeholder         : 0
# glitch              : 0
# alpha_only          : 0
# normal_number       : 0
# reversal_number     : 0
# starts_alpha        : 0
# missing_file        : 0
#
# Final dataset: 156,453 rows
#
# CSV saved:
# master_dataset_dyslexia.csv
#
# Contoh data:
#                                        image_path    file_name  split  \
# 5241      Dataset\Gambo\Test\Corrected\1_5716.png   1_5716.png   Test
# 26729         Dataset\Gambo\Test\Normal\Y-100.png    Y-100.png   Test
# 122970       Dataset\Gambo\Train\Normal\N-897.png    N-897.png  Train
# 39529   Dataset\Gambo\Train\Corrected\1_15461.png  1_15461.png  Train
# 146399   Dataset\Gambo\Train\Reversal\6_29881.png  6_29881.png  Train
#
#        folder_category  severity_score  target_class
# 5241         Corrected               1             1
# 26729           Normal               0             0
# 122970          Normal               0             0
# 39529        Corrected               1             1
# 146399        Reversal               6             1

# %% [markdown]
# ---
# # Tahap 4: Exploratory Data Analysis (EDA)
#
# Tahap ini bertujuan untuk **menggali insight visual** dari dataset yang sudah dibersihkan di Tahap 3. EDA akan menjawab pertanyaan-pertanyaan berikut:
# 1. Bagaimana distribusi jumlah gambar antar kelas dan antar split?
# 2. Apakah ada *class imbalance* yang perlu diwaspadai?
# 3. Bagaimana distribusi Severity Score (0–6)?
# 4. Seperti apa perbedaan visual antara kelas Normal, Corrected, dan Reversal?
# 5. Seperti apa perbedaan visual antara Severity Score rendah (1) dan tinggi (6)?
#
# > **Catatan:** Semua visualisasi di bawah ini menggunakan data dari `master_dataset_dyslexia.csv` yang dihasilkan di Tahap 3.

# %% [markdown]
# ### 4A. Load Data Bersih dari CSV

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np
import os

# Konfigurasi visual
sns.set_theme(style='whitegrid', palette='muted', font_scale=1.1)
plt.rcParams['figure.dpi'] = 120

# Load CSV hasil Tahap 3
df = pd.read_csv('master_dataset_dyslexia.csv')
print(f'Total data bersih: {len(df):,} baris')
print(f'Kolom: {list(df.columns)}')
print(f'\nDistribusi target_class:')
print(df['target_class'].value_counts())
df.head()
# Out:
# Total data bersih: 156,453 baris
# Kolom: ['image_path', 'file_name', 'split', 'folder_category', 'severity_score', 'target_class']
#
# Distribusi target_class:
# target_class
# 1    120463
# 0     35990
# Name: count, dtype: int64
#                                 image_path   file_name split folder_category  \
# 0     Dataset\Gambo\Test\Corrected\1_1.png     1_1.png  Test       Corrected
# 1    Dataset\Gambo\Test\Corrected\1_10.png    1_10.png  Test       Corrected
# 2   Dataset\Gambo\Test\Corrected\1_100.png   1_100.png  Test       Corrected
# 3  Dataset\Gambo\Test\Corrected\1_1000.png  1_1000.png  Test       Corrected
# 4  Dataset\Gambo\Test\Corrected\1_1001.png  1_1001.png  Test       Corrected
#
#    severity_score  target_class
# 0               1             1
# 1               1             1
# 2               1             1
# 3               1             1
# 4               1             1

# %% [markdown]
# ### 4B. Distribusi Kelas per Split (Train vs Test)
#
# Visualisasi ini menjawab: **Apakah proporsi kelas (`Normal`, `Corrected`, `Reversal`) konsisten antara set Train dan Test?**
# Jika tidak konsisten, model bisa mengalami *distribution shift* saat evaluasi.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for i, split in enumerate(['Train', 'Test']):
    data = df[df['split'] == split]['folder_category'].value_counts()
    colors = ['#2ecc71', '#e74c3c', '#3498db']
    bars = axes[i].bar(data.index, data.values, color=colors, edgecolor='white', linewidth=0.8)
    axes[i].set_title(f'Distribusi Kelas — {split}', fontweight='bold', fontsize=13)
    axes[i].set_ylabel('Jumlah Gambar')
    axes[i].set_xlabel('Kelas')
    for bar in bars:
        axes[i].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 300,
                     f'{int(bar.get_height()):,}', ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.suptitle('Distribusi Kelas Dataset per Split', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight 4B:**
# - Kelas `Corrected` mendominasi baik di Train maupun Test — ini mengindikasikan potensi *class imbalance*.
# - Kelas `Normal` paling sedikit jumlahnya, yang bisa menyebabkan model bias terhadap kelas mayoritas.
# - Proporsi relatif antar kelas cukup konsisten antara Train dan Test (tidak ada *distribution shift* yang ekstrem).

# %% [markdown]
# ### 4C. Distribusi Severity Score (0–6)
#
# Visualisasi ini menampilkan frekuensi tiap level keparahan. Skor `0` = Normal, skor `1`–`6` = Disleksia dengan derajat meningkat.

# %%
fig, ax = plt.subplots(figsize=(10, 5))

score_counts = df['severity_score'].value_counts().sort_index()
colors_severity = ['#2ecc71'] + sns.color_palette('YlOrRd', 6).as_hex()

bars = ax.bar(score_counts.index, score_counts.values, color=colors_severity,
              edgecolor='white', linewidth=0.8)

for bar in bars:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 300,
            f'{int(bar.get_height()):,}', ha='center', va='bottom', fontsize=9, fontweight='bold')

ax.set_xlabel('Severity Score', fontsize=12)
ax.set_ylabel('Jumlah Gambar', fontsize=12)
ax.set_title('Distribusi Severity Score (0 = Normal, 6 = Paling Parah)', fontweight='bold', fontsize=13)
ax.set_xticks(range(7))
ax.set_xticklabels(['0\n(Normal)', '1\n(Ringan)', '2', '3', '4', '5', '6\n(Parah)'])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight 4C:**
# - Distribusi Severity Score **tidak merata** — terdapat konsentrasi tertentu pada beberapa level.
# - Skor `0` (Normal) memiliki jumlah yang signifikan sebagai *baseline*.
# - Skor `6` (paling parah, gabungan Reversal + Corrected terparah) kemungkinan jumlahnya paling besar karena menggabungkan dua skor asli (`1` dan `4`).
# - *Class imbalance* pada level severity ini perlu ditangani saat training (misalnya via *class weights* atau *stratified sampling*).

# %% [markdown]
# ### 4D. Analisis Class Imbalance — Normal vs Disleksia (Binary)
#
# Karena tugas utama model adalah **klasifikasi biner** (`target_class`: 0 vs 1), kita perlu melihat rasio antara kedua kelas ini.

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Pie chart
target_counts = df['target_class'].value_counts().sort_index()
labels = ['Normal (0)', 'Disleksia (1)']
colors_binary = ['#2ecc71', '#e74c3c']
axes[0].pie(target_counts, labels=labels, colors=colors_binary, autopct='%1.1f%%',
            startangle=90, textprops={'fontsize': 12, 'fontweight': 'bold'},
            wedgeprops={'edgecolor': 'white', 'linewidth': 2})
axes[0].set_title('Proporsi Binary Class', fontweight='bold', fontsize=13)

# Bar chart per split
binary_split = df.groupby(['split', 'target_class']).size().unstack(fill_value=0)
binary_split.columns = labels
binary_split.plot(kind='bar', ax=axes[1], color=colors_binary, edgecolor='white', linewidth=0.8)
axes[1].set_title('Binary Class per Split', fontweight='bold', fontsize=13)
axes[1].set_ylabel('Jumlah Gambar')
axes[1].set_xlabel('')
axes[1].tick_params(axis='x', rotation=0)
axes[1].legend(loc='upper right')

for container in axes[1].containers:
    axes[1].bar_label(container, fmt='{:,.0f}', fontsize=9, fontweight='bold', padding=3)

plt.suptitle('Analisis Class Imbalance', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

ratio = target_counts[1] / target_counts[0]
print(f'Rasio Disleksia : Normal = {ratio:.2f} : 1')
print(f'Normal: {target_counts[0]:,} | Disleksia: {target_counts[1]:,}')
# Out:
# Rasio Disleksia : Normal = 3.35 : 1
# Normal: 35,990 | Disleksia: 120,463

# %% [markdown]
# **Insight 4D:**
# - Dataset bersifat **imbalanced** — kelas Disleksia jauh lebih banyak dari Normal.
# - Rasio yang tidak seimbang ini berpotensi menyebabkan model bias ke arah prediksi Disleksia.
# - **Rekomendasi mitigasi untuk AI Engineer:**
#   - Gunakan `class_weight='balanced'` atau hitung manual bobot per kelas.
#   - Pertimbangkan *stratified split* untuk memastikan kedua kelas terwakili di setiap batch.
#   - Evaluasi model dengan **F1-Score** dan **Recall**, bukan hanya Accuracy.

# %% [markdown]
# ### 4E. Sampel Visual Gambar per Kelas
#
# Menampilkan 5 sampel acak dari setiap kelas untuk memberikan gambaran visual bagaimana perbedaan pola goresan antar kelas.

# %%
fig, axes = plt.subplots(3, 5, figsize=(12, 8))

categories = ['Normal', 'Corrected', 'Reversal']
for row, cat in enumerate(categories):
    samples = df[df['folder_category'] == cat].sample(5, random_state=42)
    for col, (_, sample) in enumerate(samples.iterrows()):
        img_path = sample['image_path']
        if os.path.exists(img_path):
            img = mpimg.imread(img_path)
            axes[row][col].imshow(img, cmap='gray')
        axes[row][col].axis('off')
        if col == 0:
            axes[row][col].set_ylabel(cat, fontsize=13, fontweight='bold', rotation=0, labelpad=60)

plt.suptitle('Sampel Gambar per Kelas (5 Acak per Baris)', fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight 4E:**
# - **Normal:** Huruf terbentuk dengan jelas, satu goresan dominan, minim noise. Bentuk karakter mudah dikenali.
# - **Corrected:** Tampak goresan tumpang-tindih akibat koreksi berulang. Pola ini menghasilkan *scribbling* yang menjadi ciri khas utama disleksia tipe koreksi.
# - **Reversal:** Huruf tertulis terbalik (*mirror image*) — misalnya `b` terlihat seperti `d`, atau huruf menghadap arah berlawanan. Ini gejala klasik disleksia.

# %% [markdown]
# ### 4F. Sampel Visual per Severity Score (1 vs 3 vs 6)
#
# Perbandingan visual antara tingkat keparahan **rendah (1)**, **menengah (3)**, dan **tinggi (6)** untuk melihat apakah perbedaan derajat keparahan dapat dibedakan secara visual.

# %%
fig, axes = plt.subplots(3, 5, figsize=(12, 8))

severity_levels = [2, 4, 6]
severity_labels = ['Skor 2 (Paling Ringan)', 'Skor 4 (Menengah)', 'Skor 6 (Parah)']

for row, (score, label) in enumerate(zip(severity_levels, severity_labels)):
    samples = df[df['severity_score'] == score].sample(5, random_state=42)
    for col, (_, sample) in enumerate(samples.iterrows()):
        img_path = sample['image_path']
        if os.path.exists(img_path):
            img = mpimg.imread(img_path)
            axes[row][col].imshow(img, cmap='gray')
        axes[row][col].axis('off')
        if col == 0:
            axes[row][col].set_ylabel(label, fontsize=11, fontweight='bold', rotation=0, labelpad=80)

plt.suptitle('Perbandingan Visual Severity Score (Rendah → Tinggi)', fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight 4F:**
# - **Skor 1 (Ringan):** Goresan koreksi minimal — huruf asli masih sangat mudah dikenali. Distorsi hampir tidak terlihat.
# - **Skor 3 (Menengah):** Koreksi mulai tampak — ada goresan tambahan yang menutupi sebagian bentuk huruf asli.
# - **Skor 6 (Parah):** Goresan sangat destruktif — huruf hampir tidak bisa ditebak. Ini adalah level di mana *scribbling* sudah dominan.
#
# Perbedaan visual yang jelas antara skor rendah dan tinggi ini **mendukung hipotesis** bahwa Severity Score dapat menjadi variabel target yang bermakna untuk model AI.

# %% [markdown]
# ### 4G. Analisis Pola per Kategori: Corrected vs Reversal
#
# Membandingkan distribusi severity score **di dalam** masing-masing kelas disleksia untuk memahami karakteristik goresan yang berbeda.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for i, cat in enumerate(['Corrected', 'Reversal']):
    data = df[df['folder_category'] == cat]['severity_score'].value_counts().sort_index()
    color = '#e74c3c' if cat == 'Corrected' else '#3498db'
    bars = axes[i].bar(data.index, data.values, color=color, edgecolor='white', linewidth=0.8, alpha=0.85)
    axes[i].set_title(f'Distribusi Severity Score — {cat}', fontweight='bold', fontsize=13)
    axes[i].set_xlabel('Severity Score')
    axes[i].set_ylabel('Jumlah Gambar')
    axes[i].set_xticks(range(1, 7))
    for bar in bars:
        axes[i].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 100,
                     f'{int(bar.get_height()):,}', ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.suptitle('Pola Severity Score per Kategori Disleksia', fontsize=15, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight 4G:**
# - **Corrected:** Memiliki distribusi severity score yang lebih tersebar (skor 1–6), mencerminkan variasi tingkat koreksi tulisan dari ringan hingga ekstrem.
# - **Reversal:** Kebanyakan terkonsentrasi di skor `6` (karena skor asli `1` dari periset, yang merupakan reversal paling destruktif, dipetakan ke skor AI tertinggi).
# - Perbedaan distribusi ini menunjukkan bahwa **Corrected** dan **Reversal** memiliki karakteristik goresan yang berbeda — model bisa dilatih untuk membedakan keduanya, bukan hanya Normal vs Disleksia.

# %% [markdown]
# ### Kesimpulan EDA
#
# | Pertanyaan | Temuan |
# |---|---|
# | Distribusi kelas konsisten antar split? | ✅ Ya — proporsi relatif Train dan Test serupa |
# | Ada *class imbalance*? | ⚠️ Ya — Disleksia >> Normal. Perlu `class_weight` saat training |
# | Severity Score terdistribusi merata? | ⚠️ Tidak — skor `6` dominan karena penggabungan dua skor asli |
# | Perbedaan visual antar kelas jelas? | ✅ Ya — Normal bersih, Corrected bertumpuk, Reversal terbalik |
# | Perbedaan visual antar severity jelas? | ✅ Ya — skor rendah masih terbaca, skor tinggi destruktif |
# | Pola Corrected vs Reversal berbeda? | ✅ Ya — distribusi severity dan jenis distorsi berbeda |
#
# > **Kesimpulan Utama:** Dataset ini layak digunakan untuk klasifikasi biner (Normal vs Disleksia) maupun multi-class severity. Namun, *severity imbalance* pada skor 2–5 harus dimitigasi — dilakukan di **Tahap 5** berikut.

# %% [markdown]
# ---
# ## Visualisasi Explanatory — Menjawab Pertanyaan Bisnis
#
# Bagian ini secara eksplisit menjawab **dua pertanyaan bisnis utama** yang didefinisikan di awal notebook, menggunakan visualisasi dan analisis statistik sebagai bukti pendukung.
#
# > **Berbeda dengan EDA di atas** (yang bersifat *exploratory* / mencari pola), bagian ini bersifat **explanatory** — menyajikan jawaban yang jelas dan terstruktur.

# %% [markdown]
# ### Pertanyaan Bisnis 1: *"Apakah perbedaan distribusi visual antara kelas Normal dan Disleksia signifikan?"*

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
from PIL import Image

# --- Panel 1: Perbandingan visual side-by-side Normal vs Disleksia ---
fig, axes = plt.subplots(2, 6, figsize=(15, 5))

# Baris 1: Normal
normal_samples = df[df['target_class'] == 0].sample(6, random_state=42)
for col, (_, row) in enumerate(normal_samples.iterrows()):
    if os.path.exists(row['image_path']):
        axes[0][col].imshow(mpimg.imread(row['image_path']), cmap='gray')
    
    # PERBAIKAN: Sembunyikan ticks dan garis, JANGAN matikan axis sepenuhnya agar y-label muncul
    axes[0][col].set_xticks([])
    axes[0][col].set_yticks([])
    for spine in axes[0][col].spines.values():
        spine.set_visible(False)
        
    if col == 0:
        axes[0][col].set_ylabel('Normal', fontsize=13, fontweight='bold', rotation=0, labelpad=40, va='center')

# Baris 2: Disleksia (campuran Corrected & Reversal)
dys_samples = df[df['target_class'] == 1].sample(6, random_state=42)
for col, (_, row) in enumerate(dys_samples.iterrows()):
    if os.path.exists(row['image_path']):
        axes[1][col].imshow(mpimg.imread(row['image_path']), cmap='gray')
    
    # PERBAIKAN: Sembunyikan ticks dan garis
    axes[1][col].set_xticks([])
    axes[1][col].set_yticks([])
    for spine in axes[1][col].spines.values():
        spine.set_visible(False)
        
    if col == 0:
        axes[1][col].set_ylabel('Disleksia', fontsize=13, fontweight='bold', rotation=0, labelpad=40, va='center')

plt.suptitle('Pertanyaan Bisnis 1: Normal vs Disleksia — Apakah Berbeda Secara Visual?',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# --- Panel 2: Rata-rata intensitas piksel per kelas ---
def compute_mean_image(subset, n=200):
    """Hitung rata-rata piksel dari n sampel acak."""
    samples = subset.sample(min(n, len(subset)), random_state=42)
    arrays = []
    for _, row in samples.iterrows():
        try:
            img = Image.open(row['image_path']).convert('L').resize((28, 28))
            arrays.append(np.array(img, dtype=np.float32))
        except:
            continue
    return np.mean(arrays, axis=0) if len(arrays) > 0 else np.zeros((28,28))

mean_normal = compute_mean_image(df[df['target_class'] == 0])
mean_dys = compute_mean_image(df[df['target_class'] == 1])

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].imshow(mean_normal, cmap='gray')
axes[0].set_title('Rata-rata Normal', fontweight='bold')
axes[0].axis('off')
axes[1].imshow(mean_dys, cmap='gray')
axes[1].set_title('Rata-rata Disleksia', fontweight='bold')
axes[1].axis('off')
axes[2].imshow(np.abs(mean_normal - mean_dys), cmap='hot')
axes[2].set_title('Perbedaan (|Normal - Disleksia|)', fontweight='bold')
axes[2].axis('off')

plt.suptitle('Heatmap Rata-rata Piksel: Normal vs Disleksia', fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

diff = np.mean(np.abs(mean_normal - mean_dys))
print(f'Rata-rata selisih intensitas piksel: {diff:.2f} (dari skala 0-255)')
print(f'Semakin tinggi nilainya, semakin jelas perbedaan distribusi visual.')
# Out:
# Rata-rata selisih intensitas piksel: 8.40 (dari skala 0-255)
# Semakin tinggi nilainya, semakin jelas perbedaan distribusi visual.

# %% [markdown]
# **Jawaban Pertanyaan Bisnis 1:**
#
# > ✅ **Ya, perbedaan distribusi visual antara kelas Normal dan Disleksia signifikan.**
#
# Bukti pendukung:
# 1. **Sampel visual** menunjukkan pola goresan yang jelas berbeda — Normal memiliki garis bersih dan tegas, sementara Disleksia menampilkan goresan tumpang-tindih (*scribbling*) atau pembalikan arah huruf.
# 2. **Heatmap rata-rata piksel** memperlihatkan bahwa distribusi kegelapan antar kelas berbeda secara terukur — area yang menyala di *heatmap* perbedaan menunjukkan zona di mana pola goresan disleksia paling menyimpang dari Normal.
# 3. Temuan ini **mendukung hipotesis awal**: *"Tulisan dari penderita disleksia memiliki pola goresan yang secara visual dapat dibedakan dari tulisan normal."*

# %% [markdown]
# ### Pertanyaan Bisnis 2: *"Apakah Severity Score 6 secara visual jauh berbeda dari Severity Score 1?"*

# %%
# --- Perbandingan visual langsung: Skor 1 vs Skor 6 ---
# PERBAIKAN: Gunakan subplot 2 baris agar pemanggilan axes[0] dan axes[1] tidak error
fig, axes = plt.subplots(2, 6, figsize=(15, 5)) 

# Baris 1: Skor 1 (Paling Ringan)
score1_samples = df[df['severity_score'] == 1].sample(6, random_state=42)
for col, (_, row) in enumerate(score1_samples.iterrows()):
    if os.path.exists(row['image_path']):
        axes[0][col].imshow(mpimg.imread(row['image_path']), cmap='gray')
    
    # PERBAIKAN: Sembunyikan ticks dan garis, jangan matikan seluruh axis
    axes[0][col].set_xticks([])
    axes[0][col].set_yticks([])
    for spine in axes[0][col].spines.values():
        spine.set_visible(False)
        
    if col == 0:
        axes[0][col].set_ylabel('Skor 1\n(Ringan)', fontsize=12, fontweight='bold', rotation=0, labelpad=40, va='center')

# Baris 2: Skor 6 (Paling Parah)
score6_samples = df[df['severity_score'] == 6].sample(6, random_state=42)
for col, (_, row) in enumerate(score6_samples.iterrows()):
    if os.path.exists(row['image_path']):
        axes[1][col].imshow(mpimg.imread(row['image_path']), cmap='gray')
    
    # PERBAIKAN: Sembunyikan ticks dan garis
    axes[1][col].set_xticks([])
    axes[1][col].set_yticks([])
    for spine in axes[1][col].spines.values():
        spine.set_visible(False)
        
    if col == 0:
        axes[1][col].set_ylabel('Skor 6\n(Parah)', fontsize=12, fontweight='bold', rotation=0, labelpad=40, va='center')

plt.suptitle('Pertanyaan Bisnis 2: Severity Score 1 vs 6 — Apakah Berbeda?',
             fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# --- Heatmap rata-rata: Skor 1 vs Skor 6 ---
mean_s1 = compute_mean_image(df[df['severity_score'] == 1])
mean_s6 = compute_mean_image(df[df['severity_score'] == 6])

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].imshow(mean_s1, cmap='gray')
axes[0].set_title('Rata-rata Skor 1 (Ringan)', fontweight='bold')
axes[0].axis('off')
axes[1].imshow(mean_s6, cmap='gray')
axes[1].set_title('Rata-rata Skor 6 (Parah)', fontweight='bold')
axes[1].axis('off')
axes[2].imshow(np.abs(mean_s1 - mean_s6), cmap='hot')
axes[2].set_title('Perbedaan (|Skor 1 - Skor 6|)', fontweight='bold')
axes[2].axis('off')

plt.suptitle('Heatmap Rata-rata Piksel: Skor 1 vs Skor 6', fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

diff_sev = np.mean(np.abs(mean_s1 - mean_s6))
print(f'Rata-rata selisih intensitas piksel: {diff_sev:.2f} (dari skala 0-255)')
print(f'Semakin tinggi, semakin jelas perbedaan antara keparahan ringan dan parah.')
# Out:
# Rata-rata selisih intensitas piksel: 12.99 (dari skala 0-255)
# Semakin tinggi, semakin jelas perbedaan antara keparahan ringan dan parah.

# %% [markdown]
# **Jawaban Pertanyaan Bisnis 2:**
#
# > ✅ **Ya, Severity Score 6 secara visual jauh berbeda dari Severity Score 1.**
#
# Bukti pendukung:
# 1. **Sampel visual** menunjukkan perbedaan mencolok — Skor 1 masih menampilkan huruf yang terbaca jelas, sementara Skor 6 hampir sepenuhnya tertutup *scribbling* destruktif.
# 2. **Heatmap perbedaan** menunjukkan area selisih yang tersebar luas, mengindikasikan bahwa pola piksel antara kedua skor sangat berbeda secara kuantitatif.
# 3. Temuan ini **mendukung hipotesis awal**: *"Tingkat keparahan goresan dapat dikuantifikasi secara bertingkat"* — model AI memiliki landasan visual yang kuat untuk membedakan derajat keparahan.

# %% [markdown]
# ### Kesimpulan Explanatory Analysis
#
# | Pertanyaan Bisnis | Jawaban | Bukti |
# |---|---|---|
# | Apakah perbedaan distribusi visual Normal vs Disleksia signifikan? | ✅ **Ya** | Sampel visual + heatmap rata-rata piksel |
# | Apakah Severity Score 6 berbeda dari Score 1? | ✅ **Ya** | Sampel visual + heatmap perbedaan intensitas |
#
# **Kedua hipotesis awal TERBUKTI didukung oleh data.**
#
# Implikasi untuk proyek DyslexiaLens:
# 1. Model CNN **layak dan memungkinkan** untuk membedakan Normal vs Disleksia berdasarkan pola goresan.
# 2. Skala severity (0–6) memiliki **dasar visual yang kuat** — bukan sekadar label arbitrer, tetapi merepresentasikan perbedaan nyata pada tingkat piksel.
# 3. Sistem DyslexiaLens akan mampu memberikan output berupa **skor keparahan yang bermakna**, bukan hanya klasifikasi biner Ya/Tidak.

# %% [markdown]
# ---
# # Tahap 5: Stratified Split & Persiapan Handover
#
# Tahap ini membagi data bersih menjadi **3 set** (Train / Validation / Test) dan menyiapkan seluruh informasi yang dibutuhkan AI Engineer.
#
# ### Pendekatan: Data Bersih Tanpa Augmentasi Fisik
#
# Berdasarkan analisis EDA, kami memilih pendekatan **konservatif** di mana:
# - Data Scientist menyiapkan **data bersih + split yang seimbang**
# - Augmentasi dilakukan **secara on-the-fly** oleh AI Engineer di training pipeline (via `ImageDataGenerator` atau `tf.data.Dataset`)
#
# **Alasan:**
# 1. Menghindari *distribution shift* antara Train dan Validation/Test
# 2. Augmentasi on-the-fly menghasilkan variasi **tak terbatas** (tidak terbatas 4 copy)
# 3. AI Engineer memiliki fleksibilitas penuh untuk menyesuaikan parameter augmentasi sesuai kebutuhan model
# 4. Mencegah potensi **data leakage** dari augmentasi offline
#
# > 📦 **Versi alternatif** dengan augmentasi offline tersedia di `Dyslexia_OfflineAugmentation.ipynb`

# %% [markdown]
# ### 5A. Stratified Split: Train → Train_actual + Validation

# %%
import os
import shutil
import re
from collections import defaultdict
import random

# ========== KONFIGURASI ==========
base_path = "Dataset/Gambo"
train_dir = os.path.join(base_path, "train", "Normal")
val_dir   = os.path.join(base_path, "Validation", "Normal")   # baru
test_dir  = os.path.join(base_path, "test", "Normal")

# Huruf O sampai Z
allowed_letters = set("OPQRSTUVWXYZ")

# Rasio pembagian dari file test awal (per huruf)
# Contoh: 40% ke train, 20% ke validation, sisanya (40%) tetap di test
train_ratio = 0.4
val_ratio   = 0.2
# test_ratio = 1 - train_ratio - val_ratio (otomatis)

# Minimal 1 file untuk train dan validation jika jumlah memungkinkan
min_per_letter_train = 1
min_per_letter_val   = 1

random.seed(42)  # supaya hasil konsisten
# =================================

def get_prefix(filename):
    match = re.match(r'^([A-Z])-', filename)
    return match.group(1) if match else None

# Buat folder validation jika belum ada
os.makedirs(val_dir, exist_ok=True)

# Kumpulkan file test berdasarkan huruf awal
test_files = defaultdict(list)
for f in os.listdir(test_dir):
    if os.path.isfile(os.path.join(test_dir, f)):
        prefix = get_prefix(f)
        if prefix and prefix in allowed_letters:
            test_files[prefix].append(f)

print("File test per huruf (O-Z):")
for letter, files in sorted(test_files.items()):
    print(f"{letter}: {len(files)} file(s)")

# Proses setiap huruf
moved_train = 0
moved_val   = 0

for letter, files in test_files.items():
    total = len(files)
    if total == 0:
        continue

    # Tentukan jumlah ke train dan validation berdasarkan rasio
    n_train = int(total * train_ratio)
    n_val   = int(total * val_ratio)

    # Terapkan minimal jika memungkinkan (tidak melebihi total - 1 untuk train/val jika test perlu sisa)
    # Pastikan test masih punya setidaknya 1 file jika total > 2
    if total <= 2:
        # Jika total 2, kita bisa ambil 1 train, 1 test? Tapi validation butuh minimal 1? 
        # Sederhananya: jika total 2, maka 1 train, 1 test (validation 0)
        n_train = 1 if total >= 1 else 0
        n_val = 0
    else:
        n_train = max(min_per_letter_train, n_train)
        n_val   = max(min_per_letter_val, n_val)
        # Pastikan total_train + total_val <= total - 1 (sisakan setidaknya 1 untuk test)
        if n_train + n_val > total - 1:
            # Kurangi dari val dulu
            if n_val > 0:
                n_val = max(0, total - 1 - n_train)
            if n_train + n_val > total - 1:
                n_train = total - 1 - n_val

    if n_train == 0 and n_val == 0:
        print(f"Lewati {letter}: tidak ada file yang dipindah")
        continue

    # Acak urutan file (supaya pilihan tidak selalu dari awal)
    random.shuffle(files)

    # File ke train
    files_to_train = files[:n_train]
    for fname in files_to_train:
        src = os.path.join(test_dir, fname)
        dst = os.path.join(train_dir, fname)
        shutil.move(src, dst)
        moved_train += 1
        print(f"Pindah ke train: {fname}")

    # File ke validation
    files_to_val = files[n_train:n_train+n_val]
    for fname in files_to_val:
        src = os.path.join(test_dir, fname)
        dst = os.path.join(val_dir, fname)
        shutil.move(src, dst)
        moved_val += 1
        print(f"Pindah ke validation: {fname}")

    # Sisanya tetap di test (tidak dipindah)
    remaining = total - n_train - n_val
    print(f"Huruf {letter}: total={total}, train={n_train}, val={n_val}, test={remaining}")

print(f"\nSelesai.")
print(f"Total dipindah ke train: {moved_train} file")
print(f"Total dipindah ke validation: {moved_val} file")
print(f"Folder validation/Normal telah dibuat di: {val_dir}")
# Out:
# File test per huruf (O-Z):
# O: 500 file(s)
# P: 459 file(s)
# Q: 500 file(s)
# R: 454 file(s)
# S: 402 file(s)
# T: 498 file(s)
# U: 996 file(s)
# V: 410 file(s)
# W: 427 file(s)
# X: 405 file(s)
# Y: 443 file(s)
# Z: 400 file(s)
# Pindah ke train: O-264.png
# Pindah ke train: O-483.png
# Pindah ke train: O-145.png
# Pindah ke train: O-256.png
# Pindah ke train: O-153.png
# Pindah ke train: O-172.png
# Pindah ke train: O-415.png
# Pindah ke train: O-309.png
# Pindah ke train: O-174.png
# Pindah ke train: O-433.png
# Pindah ke train: O-503.png
# Pindah ke train: O-515.png
# Pindah ke train: O-192.png
# Pindah ke train: O-315.png
# Pindah ke train: O-579.png
# Pindah ke train: O-159.png
# Pindah ke train: O-468.png
# Pindah ke train: O-263.png
# Pindah ke train: O-310.png
# Pindah ke train: O-351.png
# Pindah ke train: O-543.png
# Pindah ke train: O-420.png
# Pindah ke train: O-389.png
# Pindah ke train: O-489.png
# Pindah ke train: O-107.png
# Pindah ke train: O-562.png
# Pindah ke train: O-349.png
# Pindah ke train: O-328.png
# Pindah ke train: O-345.png
# Pindah ke train: O-311.png
# Pindah ke train: O-229.png
# Pindah ke train: O-262.png
# Pindah ke train: O-323.png
# Pindah ke train: O-141.png
# Pindah ke train: O-378.png
# Pindah ke train: O-121.png
# Pindah ke train: O-534.png
# Pindah ke train: O-168.png
# Pindah ke train: O-327.png
# Pindah ke train: O-251.png
# Pindah ke train: O-469.png
# Pindah ke train: O-317.png
# Pindah ke train: O-254.png
# Pindah ke train: O-277.png
# Pindah ke train: O-497.png
# Pindah ke train: O-239.png
# Pindah ke train: O-241.png
# Pindah ke train: O-426.png
# Pindah ke train: O-275.png
# Pindah ke train: O-270.png
# Pindah ke train: O-188.png
# Pindah ke train: O-196.png
# Pindah ke train: O-539.png
# Pindah ke train: O-403.png
# Pindah ke train: O-150.png
# Pindah ke train: O-299.png
# Pindah ke train: O-397.png
# Pindah ke train: O-231.png
# Pindah ke train: O-220.png
# Pindah ke train: O-458.png
# Pindah ke train: O-280.png
# Pindah ke train: O-470.png
# Pindah ke train: O-137.png
# Pindah ke train: O-260.png
# Pindah ke train: O-104.png
# Pindah ke train: O-193.png
# Pindah ke train: O-404.png
# Pindah ke train: O-288.png
# Pindah ke train: O-474.png
# Pindah ke train: O-553.png
# Pindah ke train: O-194.png
# Pindah ke train: O-568.png
# Pindah ke train: O-392.png
# Pindah ke train: O-440.png
# Pindah ke train: O-507.png
# Pindah ke train: O-508.png
# Pindah ke train: O-287.png
# Pindah ke train: O-434.png
# Pindah ke train: O-313.png
# Pindah ke train: O-227.png
# Pindah ke train: O-111.png
# Pindah ke train: O-106.png
# Pindah ke train: O-542.png
# Pindah ke train: O-346.png
# Pindah ke train: O-496.png
# Pindah ke train: O-525.png
# Pindah ke train: O-445.png
# Pindah ke train: O-189.png
# Pindah ke train: O-526.png
# Pindah ke train: O-126.png
# Pindah ke train: O-177.png
# Pindah ke train: O-284.png
# Pindah ke train: O-362.png
# Pindah ke train: O-307.png
# Pindah ke train: O-282.png
# Pindah ke train: O-195.png
# Pindah ke train: O-200.png
# Pindah ke train: O-519.png
# Pindah ke train: O-494.png
# Pindah ke train: O-255.png
# Pindah ke train: O-330.png
# Pindah ke train: O-462.png
# Pindah ke train: O-337.png
# Pindah ke train: O-453.png
# Pindah ke train: O-185.png
# Pindah ke train: O-423.png
# Pindah ke train: O-271.png
# Pindah ke train: O-493.png
# Pindah ke train: O-253.png
# Pindah ke train: O-413.png
# Pindah ke train: O-138.png
# Pindah ke train: O-492.png
# Pindah ke train: O-169.png
# Pindah ke train: O-206.png
# Pindah ke train: O-448.png
# Pindah ke train: O-589.png
# Pindah ke train: O-528.png
# Pindah ke train: O-258.png
# Pindah ke train: O-131.png
# Pindah ke train: O-344.png
# Pindah ke train: O-108.png
# Pindah ke train: O-367.png
# Pindah ke train: O-585.png
# Pindah ke train: O-333.png
# Pindah ke train: O-361.png
# Pindah ke train: O-501.png
# Pindah ke train: O-391.png
# Pindah ke train: O-298.png
# Pindah ke train: O-232.png
# Pindah ke train: O-424.png
# Pindah ke train: O-422.png
# Pindah ke train: O-102.png
# Pindah ke train: O-118.png
# Pindah ke train: O-588.png
# Pindah ke train: O-363.png
# Pindah ke train: O-176.png
# Pindah ke train: O-353.png
# Pindah ke train: O-414.png
# Pindah ke train: O-451.png
# Pindah ke train: O-571.png
# Pindah ke train: O-243.png
# Pindah ke train: O-549.png
# Pindah ke train: O-166.png
# Pindah ke train: O-279.png
# Pindah ke train: O-233.png
# Pindah ke train: O-244.png
# Pindah ke train: O-506.png
# Pindah ke train: O-380.png
# Pindah ke train: O-369.png
# Pindah ke train: O-566.png
# Pindah ke train: O-308.png
# Pindah ke train: O-245.png
# Pindah ke train: O-532.png
# Pindah ke train: O-377.png
# Pindah ke train: O-441.png
# Pindah ke train: O-565.png
# Pindah ke train: O-417.png
# Pindah ke train: O-117.png
# Pindah ke train: O-548.png
# Pindah ke train: O-120.png
# Pindah ke train: O-230.png
# Pindah ke train: O-338.png
# Pindah ke train: O-396.png
# Pindah ke train: O-386.png
# Pindah ke train: O-436.png
# Pindah ke train: O-400.png
# Pindah ke train: O-249.png
# Pindah ke train: O-303.png
# Pindah ke train: O-487.png
# Pindah ke train: O-498.png
# Pindah ke train: O-290.png
# Pindah ke train: O-301.png
# Pindah ke train: O-518.png
# Pindah ke train: O-114.png
# Pindah ke train: O-155.png
# Pindah ke train: O-175.png
# Pindah ke train: O-384.png
# Pindah ke train: O-139.png
# Pindah ke train: O-491.png
# Pindah ke train: O-560.png
# Pindah ke train: O-357.png
# Pindah ke train: O-278.png
# Pindah ke train: O-312.png
# Pindah ke train: O-572.png
# Pindah ke train: O-520.png
# Pindah ke train: O-167.png
# Pindah ke train: O-199.png
# Pindah ke train: O-576.png
# Pindah ke train: O-197.png
# Pindah ke train: O-296.png
# Pindah ke train: O-439.png
# Pindah ke train: O-388.png
# Pindah ke train: O-418.png
# Pindah ke train: O-557.png
# Pindah ke train: O-224.png
# Pindah ke train: O-342.png
# Pindah ke train: O-142.png
# Pindah ke train: O-160.png
# Pindah ke train: O-292.png
# Pindah ke train: O-522.png
# Pindah ke validation: O-366.png
# Pindah ke validation: O-354.png
# Pindah ke validation: O-484.png
# Pindah ke validation: O-597.png
# Pindah ke validation: O-326.png
# Pindah ke validation: O-595.png
# Pindah ke validation: O-213.png
# Pindah ke validation: O-119.png
# Pindah ke validation: O-318.png
# Pindah ke validation: O-218.png
# Pindah ke validation: O-464.png
# Pindah ke validation: O-485.png
# Pindah ke validation: O-537.png
# Pindah ke validation: O-393.png
# Pindah ke validation: O-593.png
# Pindah ke validation: O-478.png
# Pindah ke validation: O-341.png
# Pindah ke validation: O-546.png
# Pindah ke validation: O-535.png
# Pindah ke validation: O-127.png
# Pindah ke validation: O-320.png
# Pindah ke validation: O-569.png
# Pindah ke validation: O-186.png
# Pindah ke validation: O-461.png
# Pindah ke validation: O-203.png
# Pindah ke validation: O-581.png
# Pindah ke validation: O-125.png
# Pindah ke validation: O-407.png
# Pindah ke validation: O-267.png
# Pindah ke validation: O-550.png
# Pindah ke validation: O-575.png
# Pindah ke validation: O-510.png
# Pindah ke validation: O-321.png
# Pindah ke validation: O-516.png
# Pindah ke validation: O-205.png
# Pindah ke validation: O-471.png
# Pindah ke validation: O-190.png
# Pindah ke validation: O-552.png
# Pindah ke validation: O-268.png
# Pindah ke validation: O-340.png
# Pindah ke validation: O-502.png
# Pindah ke validation: O-148.png
# Pindah ke validation: O-204.png
# Pindah ke validation: O-306.png
# Pindah ke validation: O-347.png
# Pindah ke validation: O-300.png
# Pindah ke validation: O-162.png
# Pindah ke validation: O-577.png
# Pindah ke validation: O-247.png
# Pindah ke validation: O-246.png
# Pindah ke validation: O-325.png
# Pindah ke validation: O-521.png
# Pindah ke validation: O-584.png
# Pindah ke validation: O-591.png
# Pindah ke validation: O-551.png
# Pindah ke validation: O-209.png
# Pindah ke validation: O-394.png
# Pindah ke validation: O-540.png
# Pindah ke validation: O-221.png
# Pindah ke validation: O-365.png
# Pindah ke validation: O-269.png
# Pindah ke validation: O-481.png
# Pindah ke validation: O-134.png
# Pindah ke validation: O-368.png
# Pindah ke validation: O-130.png
# Pindah ke validation: O-500.png
# Pindah ke validation: O-561.png
# Pindah ke validation: O-454.png
# Pindah ke validation: O-482.png
# Pindah ke validation: O-110.png
# Pindah ke validation: O-273.png
# Pindah ke validation: O-442.png
# Pindah ke validation: O-215.png
# Pindah ke validation: O-463.png
# Pindah ke validation: O-161.png
# Pindah ke validation: O-331.png
# Pindah ke validation: O-364.png
# Pindah ke validation: O-324.png
# Pindah ke validation: O-412.png
# Pindah ke validation: O-456.png
# Pindah ke validation: O-259.png
# Pindah ke validation: O-202.png
# Pindah ke validation: O-410.png
# Pindah ke validation: O-472.png
# Pindah ke validation: O-444.png
# Pindah ke validation: O-437.png
# Pindah ke validation: O-465.png
# Pindah ke validation: O-184.png
# Pindah ke validation: O-381.png
# Pindah ke validation: O-343.png
# Pindah ke validation: O-165.png
# Pindah ke validation: O-164.png
# Pindah ke validation: O-372.png
# Pindah ke validation: O-523.png
# Pindah ke validation: O-348.png
# Pindah ke validation: O-143.png
# Pindah ke validation: O-517.png
# Pindah ke validation: O-475.png
# Pindah ke validation: O-223.png
# Pindah ke validation: O-129.png
# Huruf O: total=500, train=200, val=100, test=200
# Pindah ke train: P-150.png
# Pindah ke train: P-434.png
# Pindah ke train: P-420.png
# Pindah ke train: P-371.png
# Pindah ke train: P-28.png
# Pindah ke train: P-381.png
# Pindah ke train: P-27.png
# Pindah ke train: P-281.png
# Pindah ke train: P-282.png
# Pindah ke train: P-337.png
# Pindah ke train: P-330.png
# Pindah ke train: P-67.png
# Pindah ke train: P-199.png
# Pindah ke train: P-144.png
# Pindah ke train: P-174.png
# Pindah ke train: P-166.png
# Pindah ke train: P-274.png
# Pindah ke train: P-13.png
# Pindah ke train: P-389.png
# Pindah ke train: P-419.png
# Pindah ke train: P-459.png
# Pindah ke train: P-367.png
# Pindah ke train: P-292.png
# Pindah ke train: P-169.png
# Pindah ke train: P-87.png
# Pindah ke train: P-179.png
# Pindah ke train: P-433.png
# Pindah ke train: P-416.png
# Pindah ke train: P-242.png
# Pindah ke train: P-89.png
# Pindah ke train: P-304.png
# Pindah ke train: P-478.png
# Pindah ke train: P-71.png
# Pindah ke train: P-85.png
# Pindah ke train: P-106.png
# Pindah ke train: P-74.png
# Pindah ke train: P-362.png
# Pindah ke train: P-148.png
# Pindah ke train: P-345.png
# Pindah ke train: P-413.png
# Pindah ke train: P-325.png
# Pindah ke train: P-51.png
# Pindah ke train: P-361.png
# Pindah ke train: P-454.png
# Pindah ke train: P-396.png
# Pindah ke train: P-118.png
# Pindah ke train: P-379.png
# Pindah ke train: P-346.png
# Pindah ke train: P-340.png
# Pindah ke train: P-198.png
# Pindah ke train: P-165.png
# Pindah ke train: P-482.png
# Pindah ke train: P-360.png
# Pindah ke train: P-197.png
# Pindah ke train: P-143.png
# Pindah ke train: P-442.png
# Pindah ke train: P-105.png
# Pindah ke train: P-263.png
# Pindah ke train: P-115.png
# Pindah ke train: P-440.png
# Pindah ke train: P-473.png
# Pindah ke train: P-202.png
# Pindah ke train: P-261.png
# Pindah ke train: P-112.png
# Pindah ke train: P-1.png
# Pindah ke train: P-134.png
# Pindah ke train: P-466.png
# Pindah ke train: P-229.png
# Pindah ke train: P-72.png
# Pindah ke train: P-20.png
# Pindah ke train: P-58.png
# Pindah ke train: P-450.png
# Pindah ke train: P-132.png
# Pindah ke train: P-19.png
# Pindah ke train: P-7.png
# Pindah ke train: P-62.png
# Pindah ke train: P-255.png
# Pindah ke train: P-207.png
# Pindah ke train: P-83.png
# Pindah ke train: P-29.png
# Pindah ke train: P-358.png
# Pindah ke train: P-136.png
# Pindah ke train: P-228.png
# Pindah ke train: P-111.png
# Pindah ke train: P-294.png
# Pindah ke train: P-309.png
# Pindah ke train: P-313.png
# Pindah ke train: P-130.png
# Pindah ke train: P-152.png
# Pindah ke train: P-323.png
# Pindah ke train: P-297.png
# Pindah ke train: P-299.png
# Pindah ke train: P-284.png
# Pindah ke train: P-485.png
# Pindah ke train: P-14.png
# Pindah ke train: P-160.png
# Pindah ke train: P-221.png
# Pindah ke train: P-209.png
# Pindah ke train: P-457.png
# Pindah ke train: P-167.png
# Pindah ke train: P-356.png
# Pindah ke train: P-251.png
# Pindah ke train: P-38.png
# Pindah ke train: P-237.png
# Pindah ke train: P-96.png
# Pindah ke train: P-125.png
# Pindah ke train: P-445.png
# Pindah ke train: P-108.png
# Pindah ke train: P-464.png
# Pindah ke train: P-283.png
# Pindah ke train: P-322.png
# Pindah ke train: P-243.png
# Pindah ke train: P-186.png
# Pindah ke train: P-374.png
# Pindah ke train: P-154.png
# Pindah ke train: P-296.png
# Pindah ke train: P-402.png
# Pindah ke train: P-414.png
# Pindah ke train: P-57.png
# Pindah ke train: P-236.png
# Pindah ke train: P-147.png
# Pindah ke train: P-35.png
# Pindah ke train: P-278.png
# Pindah ke train: P-267.png
# Pindah ke train: P-121.png
# Pindah ke train: P-378.png
# Pindah ke train: P-225.png
# Pindah ke train: P-49.png
# Pindah ke train: P-393.png
# Pindah ke train: P-372.png
# Pindah ke train: P-319.png
# Pindah ke train: P-16.png
# Pindah ke train: P-429.png
# Pindah ke train: P-341.png
# Pindah ke train: P-435.png
# Pindah ke train: P-141.png
# Pindah ke train: P-34.png
# Pindah ke train: P-406.png
# Pindah ke train: P-316.png
# Pindah ke train: P-97.png
# Pindah ke train: P-336.png
# Pindah ke train: P-391.png
# Pindah ke train: P-475.png
# Pindah ke train: P-453.png
# Pindah ke train: P-335.png
# Pindah ke train: P-84.png
# Pindah ke train: P-275.png
# Pindah ke train: P-176.png
# Pindah ke train: P-421.png
# Pindah ke train: P-250.png
# Pindah ke train: P-303.png
# Pindah ke train: P-217.png
# Pindah ke train: P-231.png
# Pindah ke train: P-60.png
# Pindah ke train: P-344.png
# Pindah ke train: P-140.png
# Pindah ke train: P-205.png
# Pindah ke train: P-412.png
# Pindah ke train: P-211.png
# Pindah ke train: P-187.png
# Pindah ke train: P-204.png
# Pindah ke train: P-357.png
# Pindah ke train: P-449.png
# Pindah ke train: P-331.png
# Pindah ke train: P-53.png
# Pindah ke train: P-181.png
# Pindah ke train: P-259.png
# Pindah ke train: P-223.png
# Pindah ke train: P-320.png
# Pindah ke train: P-56.png
# Pindah ke train: P-441.png
# Pindah ke train: P-388.png
# Pindah ke train: P-230.png
# Pindah ke train: P-182.png
# Pindah ke train: P-415.png
# Pindah ke train: P-467.png
# Pindah ke train: P-127.png
# Pindah ke train: P-61.png
# Pindah ke train: P-268.png
# Pindah ke train: P-392.png
# Pindah ke train: P-270.png
# Pindah ke train: P-123.png
# Pindah ke train: P-423.png
# Pindah ke validation: P-66.png
# Pindah ke validation: P-95.png
# Pindah ke validation: P-54.png
# Pindah ke validation: P-99.png
# Pindah ke validation: P-145.png
# Pindah ke validation: P-461.png
# Pindah ke validation: P-452.png
# Pindah ke validation: P-191.png
# Pindah ke validation: P-266.png
# Pindah ke validation: P-240.png
# Pindah ke validation: P-88.png
# Pindah ke validation: P-103.png
# Pindah ke validation: P-241.png
# Pindah ke validation: P-124.png
# Pindah ke validation: P-173.png
# Pindah ke validation: P-417.png
# Pindah ke validation: P-410.png
# Pindah ke validation: P-404.png
# Pindah ke validation: P-276.png
# Pindah ke validation: P-326.png
# Pindah ke validation: P-436.png
# Pindah ke validation: P-481.png
# Pindah ke validation: P-468.png
# Pindah ke validation: P-189.png
# Pindah ke validation: P-390.png
# Pindah ke validation: P-59.png
# Pindah ke validation: P-271.png
# Pindah ke validation: P-213.png
# Pindah ke validation: P-98.png
# Pindah ke validation: P-238.png
# Pindah ke validation: P-126.png
# Pindah ke validation: P-397.png
# Pindah ke validation: P-215.png
# Pindah ke validation: P-387.png
# Pindah ke validation: P-155.png
# Pindah ke validation: P-40.png
# Pindah ke validation: P-253.png
# Pindah ke validation: P-102.png
# Pindah ke validation: P-369.png
# Pindah ke validation: P-146.png
# Pindah ke validation: P-63.png
# Pindah ke validation: P-104.png
# Pindah ke validation: P-287.png
# Pindah ke validation: P-418.png
# Pindah ke validation: P-408.png
# Pindah ke validation: P-359.png
# Pindah ke validation: P-113.png
# Pindah ke validation: P-26.png
# Pindah ke validation: P-151.png
# Pindah ke validation: P-93.png
# Pindah ke validation: P-351.png
# Pindah ke validation: P-232.png
# Pindah ke validation: P-285.png
# Pindah ke validation: P-101.png
# Pindah ke validation: P-399.png
# Pindah ke validation: P-117.png
# Pindah ke validation: P-306.png
# Pindah ke validation: P-158.png
# Pindah ke validation: P-479.png
# Pindah ke validation: P-486.png
# Pindah ke validation: P-409.png
# Pindah ke validation: P-286.png
# Pindah ke validation: P-164.png
# Pindah ke validation: P-343.png
# Pindah ke validation: P-447.png
# Pindah ke validation: P-425.png
# Pindah ke validation: P-76.png
# Pindah ke validation: P-78.png
# Pindah ke validation: P-210.png
# Pindah ke validation: P-47.png
# Pindah ke validation: P-177.png
# Pindah ke validation: P-86.png
# Pindah ke validation: P-227.png
# Pindah ke validation: P-460.png
# Pindah ke validation: P-188.png
# Pindah ke validation: P-327.png
# Pindah ke validation: P-162.png
# Pindah ke validation: P-311.png
# Pindah ke validation: P-138.png
# Pindah ke validation: P-353.png
# Pindah ke validation: P-295.png
# Pindah ke validation: P-11.png
# Pindah ke validation: P-52.png
# Pindah ke validation: P-33.png
# Pindah ke validation: P-178.png
# Pindah ke validation: P-484.png
# Pindah ke validation: P-265.png
# Pindah ke validation: P-94.png
# Pindah ke validation: P-110.png
# Pindah ke validation: P-487.png
# Pindah ke validation: P-82.png
# Huruf P: total=459, train=183, val=91, test=185
# Pindah ke train: Q-344.png
# Pindah ke train: Q-263.png
# Pindah ke train: Q-428.png
# Pindah ke train: Q-148.png
# Pindah ke train: Q-441.png
# Pindah ke train: Q-91.png
# Pindah ke train: Q-59.png
# Pindah ke train: Q-127.png
# Pindah ke train: Q-446.png
# Pindah ke train: Q-87.png
# Pindah ke train: Q-103.png
# Pindah ke train: Q-294.png
# Pindah ke train: Q-360.png
# Pindah ke train: Q-96.png
# Pindah ke train: Q-432.png
# Pindah ke train: Q-380.png
# Pindah ke train: Q-445.png
# Pindah ke train: Q-147.png
# Pindah ke train: Q-500.png
# Pindah ke train: Q-188.png
# Pindah ke train: Q-31.png
# Pindah ke train: Q-126.png
# Pindah ke train: Q-297.png
# Pindah ke train: Q-49.png
# Pindah ke train: Q-305.png
# Pindah ke train: Q-158.png
# Pindah ke train: Q-89.png
# Pindah ke train: Q-191.png
# Pindah ke train: Q-225.png
# Pindah ke train: Q-99.png
# Pindah ke train: Q-36.png
# Pindah ke train: Q-44.png
# Pindah ke train: Q-106.png
# Pindah ke train: Q-447.png
# Pindah ke train: Q-283.png
# Pindah ke train: Q-339.png
# Pindah ke train: Q-133.png
# Pindah ke train: Q-65.png
# Pindah ke train: Q-320.png
# Pindah ke train: Q-468.png
# Pindah ke train: Q-219.png
# Pindah ke train: Q-228.png
# Pindah ke train: Q-405.png
# Pindah ke train: Q-117.png
# Pindah ke train: Q-190.png
# Pindah ke train: Q-384.png
# Pindah ke train: Q-292.png
# Pindah ke train: Q-286.png
# Pindah ke train: Q-197.png
# Pindah ke train: Q-249.png
# Pindah ke train: Q-389.png
# Pindah ke train: Q-469.png
# Pindah ke train: Q-399.png
# Pindah ke train: Q-377.png
# Pindah ke train: Q-337.png
# Pindah ke train: Q-443.png
# Pindah ke train: Q-62.png
# Pindah ke train: Q-120.png
# Pindah ke train: Q-28.png
# Pindah ke train: Q-363.png
# Pindah ke train: Q-66.png
# Pindah ke train: Q-218.png
# Pindah ke train: Q-129.png
# Pindah ke train: Q-261.png
# Pindah ke train: Q-427.png
# Pindah ke train: Q-372.png
# Pindah ke train: Q-199.png
# Pindah ke train: Q-175.png
# Pindah ke train: Q-354.png
# Pindah ke train: Q-272.png
# Pindah ke train: Q-189.png
# Pindah ke train: Q-269.png
# Pindah ke train: Q-381.png
# Pindah ke train: Q-334.png
# Pindah ke train: Q-53.png
# Pindah ke train: Q-177.png
# Pindah ke train: Q-195.png
# Pindah ke train: Q-22.png
# Pindah ke train: Q-27.png
# Pindah ke train: Q-458.png
# Pindah ke train: Q-81.png
# Pindah ke train: Q-43.png
# Pindah ke train: Q-410.png
# Pindah ke train: Q-142.png
# Pindah ke train: Q-216.png
# Pindah ke train: Q-211.png
# Pindah ke train: Q-63.png
# Pindah ke train: Q-279.png
# Pindah ke train: Q-183.png
# Pindah ke train: Q-54.png
# Pindah ke train: Q-270.png
# Pindah ke train: Q-101.png
# Pindah ke train: Q-264.png
# Pindah ke train: Q-113.png
# Pindah ke train: Q-32.png
# Pindah ke train: Q-145.png
# Pindah ke train: Q-235.png
# Pindah ke train: Q-345.png
# Pindah ke train: Q-474.png
# Pindah ke train: Q-298.png
# Pindah ke train: Q-201.png
# Pindah ke train: Q-60.png
# Pindah ke train: Q-457.png
# Pindah ke train: Q-123.png
# Pindah ke train: Q-481.png
# Pindah ke train: Q-340.png
# Pindah ke train: Q-162.png
# Pindah ke train: Q-414.png
# Pindah ke train: Q-425.png
# Pindah ke train: Q-271.png
# Pindah ke train: Q-385.png
# Pindah ke train: Q-8.png
# Pindah ke train: Q-488.png
# Pindah ke train: Q-368.png
# Pindah ke train: Q-83.png
# Pindah ke train: Q-312.png
# Pindah ke train: Q-25.png
# Pindah ke train: Q-395.png
# Pindah ke train: Q-212.png
# Pindah ke train: Q-208.png
# Pindah ke train: Q-57.png
# Pindah ke train: Q-479.png
# Pindah ke train: Q-485.png
# Pindah ke train: Q-254.png
# Pindah ke train: Q-111.png
# Pindah ke train: Q-16.png
# Pindah ke train: Q-268.png
# Pindah ke train: Q-100.png
# Pindah ke train: Q-217.png
# Pindah ke train: Q-237.png
# Pindah ke train: Q-23.png
# Pindah ke train: Q-262.png
# Pindah ke train: Q-15.png
# Pindah ke train: Q-492.png
# Pindah ke train: Q-115.png
# Pindah ke train: Q-436.png
# Pindah ke train: Q-124.png
# Pindah ke train: Q-176.png
# Pindah ke train: Q-382.png
# Pindah ke train: Q-371.png
# Pindah ke train: Q-293.png
# Pindah ke train: Q-358.png
# Pindah ke train: Q-390.png
# Pindah ke train: Q-489.png
# Pindah ke train: Q-313.png
# Pindah ke train: Q-253.png
# Pindah ke train: Q-223.png
# Pindah ke train: Q-238.png
# Pindah ke train: Q-76.png
# Pindah ke train: Q-417.png
# Pindah ke train: Q-194.png
# Pindah ke train: Q-376.png
# Pindah ke train: Q-265.png
# Pindah ke train: Q-119.png
# Pindah ke train: Q-128.png
# Pindah ke train: Q-182.png
# Pindah ke train: Q-232.png
# Pindah ke train: Q-105.png
# Pindah ke train: Q-2.png
# Pindah ke train: Q-346.png
# Pindah ke train: Q-482.png
# Pindah ke train: Q-280.png
# Pindah ke train: Q-12.png
# Pindah ke train: Q-243.png
# Pindah ke train: Q-335.png
# Pindah ke train: Q-278.png
# Pindah ke train: Q-429.png
# Pindah ke train: Q-141.png
# Pindah ke train: Q-433.png
# Pindah ke train: Q-149.png
# Pindah ke train: Q-18.png
# Pindah ke train: Q-497.png
# Pindah ke train: Q-459.png
# Pindah ke train: Q-484.png
# Pindah ke train: Q-467.png
# Pindah ke train: Q-51.png
# Pindah ke train: Q-109.png
# Pindah ke train: Q-257.png
# Pindah ke train: Q-407.png
# Pindah ke train: Q-291.png
# Pindah ke train: Q-161.png
# Pindah ke train: Q-74.png
# Pindah ke train: Q-34.png
# Pindah ke train: Q-102.png
# Pindah ke train: Q-267.png
# Pindah ke train: Q-260.png
# Pindah ke train: Q-319.png
# Pindah ke train: Q-391.png
# Pindah ke train: Q-318.png
# Pindah ke train: Q-230.png
# Pindah ke train: Q-303.png
# Pindah ke train: Q-406.png
# Pindah ke train: Q-435.png
# Pindah ke train: Q-21.png
# Pindah ke train: Q-187.png
# Pindah ke train: Q-499.png
# Pindah ke train: Q-359.png
# Pindah ke train: Q-431.png
# Pindah ke train: Q-356.png
# Pindah ke train: Q-466.png
# Pindah ke validation: Q-196.png
# Pindah ke validation: Q-296.png
# Pindah ke validation: Q-465.png
# Pindah ke validation: Q-234.png
# Pindah ke validation: Q-178.png
# Pindah ke validation: Q-328.png
# Pindah ke validation: Q-440.png
# Pindah ke validation: Q-134.png
# Pindah ke validation: Q-400.png
# Pindah ke validation: Q-342.png
# Pindah ke validation: Q-498.png
# Pindah ke validation: Q-58.png
# Pindah ke validation: Q-476.png
# Pindah ke validation: Q-10.png
# Pindah ke validation: Q-374.png
# Pindah ke validation: Q-73.png
# Pindah ke validation: Q-486.png
# Pindah ke validation: Q-157.png
# Pindah ke validation: Q-246.png
# Pindah ke validation: Q-90.png
# Pindah ke validation: Q-442.png
# Pindah ke validation: Q-64.png
# Pindah ke validation: Q-402.png
# Pindah ke validation: Q-213.png
# Pindah ke validation: Q-153.png
# Pindah ke validation: Q-310.png
# Pindah ke validation: Q-241.png
# Pindah ke validation: Q-393.png
# Pindah ke validation: Q-355.png
# Pindah ke validation: Q-24.png
# Pindah ke validation: Q-477.png
# Pindah ke validation: Q-138.png
# Pindah ke validation: Q-137.png
# Pindah ke validation: Q-331.png
# Pindah ke validation: Q-281.png
# Pindah ke validation: Q-387.png
# Pindah ke validation: Q-383.png
# Pindah ke validation: Q-193.png
# Pindah ke validation: Q-343.png
# Pindah ke validation: Q-42.png
# Pindah ke validation: Q-131.png
# Pindah ke validation: Q-198.png
# Pindah ke validation: Q-184.png
# Pindah ke validation: Q-180.png
# Pindah ke validation: Q-166.png
# Pindah ke validation: Q-454.png
# Pindah ke validation: Q-350.png
# Pindah ke validation: Q-173.png
# Pindah ke validation: Q-108.png
# Pindah ke validation: Q-491.png
# Pindah ke validation: Q-307.png
# Pindah ke validation: Q-379.png
# Pindah ke validation: Q-259.png
# Pindah ke validation: Q-136.png
# Pindah ke validation: Q-200.png
# Pindah ke validation: Q-351.png
# Pindah ke validation: Q-143.png
# Pindah ke validation: Q-3.png
# Pindah ke validation: Q-61.png
# Pindah ke validation: Q-203.png
# Pindah ke validation: Q-423.png
# Pindah ke validation: Q-207.png
# Pindah ke validation: Q-418.png
# Pindah ke validation: Q-357.png
# Pindah ke validation: Q-323.png
# Pindah ke validation: Q-367.png
# Pindah ke validation: Q-274.png
# Pindah ke validation: Q-456.png
# Pindah ke validation: Q-495.png
# Pindah ke validation: Q-282.png
# Pindah ke validation: Q-255.png
# Pindah ke validation: Q-80.png
# Pindah ke validation: Q-463.png
# Pindah ke validation: Q-132.png
# Pindah ke validation: Q-17.png
# Pindah ke validation: Q-461.png
# Pindah ke validation: Q-164.png
# Pindah ke validation: Q-412.png
# Pindah ke validation: Q-77.png
# Pindah ke validation: Q-341.png
# Pindah ke validation: Q-6.png
# Pindah ke validation: Q-301.png
# Pindah ke validation: Q-144.png
# Pindah ke validation: Q-251.png
# Pindah ke validation: Q-330.png
# Pindah ke validation: Q-156.png
# Pindah ke validation: Q-475.png
# Pindah ke validation: Q-453.png
# Pindah ke validation: Q-168.png
# Pindah ke validation: Q-277.png
# Pindah ke validation: Q-275.png
# Pindah ke validation: Q-317.png
# Pindah ke validation: Q-245.png
# Pindah ke validation: Q-118.png
# Pindah ke validation: Q-455.png
# Pindah ke validation: Q-82.png
# Pindah ke validation: Q-394.png
# Pindah ke validation: Q-362.png
# Pindah ke validation: Q-52.png
# Pindah ke validation: Q-434.png
# Huruf Q: total=500, train=200, val=100, test=200
# Pindah ke train: R-10.png
# Pindah ke train: R-322.png
# Pindah ke train: R-330.png
# Pindah ke train: R-191.png
# Pindah ke train: R-317.png
# Pindah ke train: R-7.png
# Pindah ke train: R-166.png
# Pindah ke train: R-105.png
# Pindah ke train: R-0.png
# Pindah ke train: R-102.png
# Pindah ke train: R-457.png
# Pindah ke train: R-350.png
# Pindah ke train: R-357.png
# Pindah ke train: R-306.png
# Pindah ke train: R-220.png
# Pindah ke train: R-417.png
# Pindah ke train: R-353.png
# Pindah ke train: R-182.png
# Pindah ke train: R-378.png
# Pindah ke train: R-97.png
# Pindah ke train: R-230.png
# Pindah ke train: R-155.png
# Pindah ke train: R-153.png
# Pindah ke train: R-146.png
# Pindah ke train: R-465.png
# Pindah ke train: R-399.png
# Pindah ke train: R-43.png
# Pindah ke train: R-88.png
# Pindah ke train: R-300.png
# Pindah ke train: R-451.png
# Pindah ke train: R-60.png
# Pindah ke train: R-334.png
# Pindah ke train: R-51.png
# Pindah ke train: R-404.png
# Pindah ke train: R-197.png
# Pindah ke train: R-428.png
# Pindah ke train: R-379.png
# Pindah ke train: R-71.png
# Pindah ke train: R-236.png
# Pindah ke train: R-320.png
# Pindah ke train: R-237.png
# Pindah ke train: R-195.png
# Pindah ke train: R-370.png
# Pindah ke train: R-265.png
# Pindah ke train: R-415.png
# Pindah ke train: R-73.png
# Pindah ke train: R-165.png
# Pindah ke train: R-72.png
# Pindah ke train: R-315.png
# Pindah ke train: R-252.png
# Pindah ke train: R-406.png
# Pindah ke train: R-30.png
# Pindah ke train: R-226.png
# Pindah ke train: R-75.png
# Pindah ke train: R-74.png
# Pindah ke train: R-281.png
# Pindah ke train: R-437.png
# Pindah ke train: R-460.png
# Pindah ke train: R-207.png
# Pindah ke train: R-205.png
# Pindah ke train: R-223.png
# Pindah ke train: R-438.png
# Pindah ke train: R-464.png
# Pindah ke train: R-290.png
# Pindah ke train: R-343.png
# Pindah ke train: R-477.png
# Pindah ke train: R-268.png
# Pindah ke train: R-366.png
# Pindah ke train: R-120.png
# Pindah ke train: R-380.png
# Pindah ke train: R-267.png
# Pindah ke train: R-86.png
# Pindah ke train: R-250.png
# Pindah ke train: R-362.png
# Pindah ke train: R-189.png
# Pindah ke train: R-100.png
# Pindah ke train: R-401.png
# Pindah ke train: R-29.png
# Pindah ke train: R-150.png
# Pindah ke train: R-109.png
# Pindah ke train: R-162.png
# Pindah ke train: R-364.png
# Pindah ke train: R-200.png
# Pindah ke train: R-278.png
# Pindah ke train: R-87.png
# Pindah ke train: R-436.png
# Pindah ke train: R-253.png
# Pindah ke train: R-447.png
# Pindah ke train: R-247.png
# Pindah ke train: R-113.png
# Pindah ke train: R-66.png
# Pindah ke train: R-199.png
# Pindah ke train: R-61.png
# Pindah ke train: R-33.png
# Pindah ke train: R-94.png
# Pindah ke train: R-232.png
# Pindah ke train: R-41.png
# Pindah ke train: R-331.png
# Pindah ke train: R-461.png
# Pindah ke train: R-231.png
# Pindah ke train: R-318.png
# Pindah ke train: R-287.png
# Pindah ke train: R-448.png
# Pindah ke train: R-185.png
# Pindah ke train: R-48.png
# Pindah ke train: R-129.png
# Pindah ke train: R-222.png
# Pindah ke train: R-221.png
# Pindah ke train: R-218.png
# Pindah ke train: R-17.png
# Pindah ke train: R-11.png
# Pindah ke train: R-266.png
# Pindah ke train: R-106.png
# Pindah ke train: R-138.png
# Pindah ke train: R-241.png
# Pindah ke train: R-270.png
# Pindah ke train: R-81.png
# Pindah ke train: R-104.png
# Pindah ke train: R-176.png
# Pindah ke train: R-383.png
# Pindah ke train: R-304.png
# Pindah ke train: R-20.png
# Pindah ke train: R-148.png
# Pindah ke train: R-299.png
# Pindah ke train: R-435.png
# Pindah ke train: R-91.png
# Pindah ke train: R-458.png
# Pindah ke train: R-193.png
# Pindah ke train: R-136.png
# Pindah ke train: R-3.png
# Pindah ke train: R-410.png
# Pindah ke train: R-159.png
# Pindah ke train: R-338.png
# Pindah ke train: R-352.png
# Pindah ke train: R-56.png
# Pindah ke train: R-347.png
# Pindah ke train: R-188.png
# Pindah ke train: R-328.png
# Pindah ke train: R-57.png
# Pindah ke train: R-420.png
# Pindah ke train: R-277.png
# Pindah ke train: R-227.png
# Pindah ke train: R-22.png
# Pindah ke train: R-272.png
# Pindah ke train: R-470.png
# Pindah ke train: R-273.png
# Pindah ke train: R-108.png
# Pindah ke train: R-24.png
# Pindah ke train: R-279.png
# Pindah ke train: R-398.png
# Pindah ke train: R-2.png
# Pindah ke train: R-335.png
# Pindah ke train: R-25.png
# Pindah ke train: R-369.png
# Pindah ke train: R-469.png
# Pindah ke train: R-407.png
# Pindah ke train: R-194.png
# Pindah ke train: R-294.png
# Pindah ke train: R-345.png
# Pindah ke train: R-423.png
# Pindah ke train: R-367.png
# Pindah ke train: R-443.png
# Pindah ke train: R-115.png
# Pindah ke train: R-229.png
# Pindah ke train: R-190.png
# Pindah ke train: R-414.png
# Pindah ke train: R-249.png
# Pindah ke train: R-361.png
# Pindah ke train: R-177.png
# Pindah ke train: R-258.png
# Pindah ke train: R-212.png
# Pindah ke train: R-219.png
# Pindah ke train: R-114.png
# Pindah ke train: R-69.png
# Pindah ke train: R-134.png
# Pindah ke train: R-340.png
# Pindah ke train: R-427.png
# Pindah ke train: R-183.png
# Pindah ke train: R-394.png
# Pindah ke train: R-445.png
# Pindah ke train: R-77.png
# Pindah ke validation: R-28.png
# Pindah ke validation: R-53.png
# Pindah ke validation: R-430.png
# Pindah ke validation: R-400.png
# Pindah ke validation: R-242.png
# Pindah ke validation: R-217.png
# Pindah ke validation: R-225.png
# Pindah ke validation: R-468.png
# Pindah ke validation: R-140.png
# Pindah ke validation: R-325.png
# Pindah ke validation: R-359.png
# Pindah ke validation: R-135.png
# Pindah ke validation: R-363.png
# Pindah ke validation: R-14.png
# Pindah ke validation: R-59.png
# Pindah ke validation: R-160.png
# Pindah ke validation: R-293.png
# Pindah ke validation: R-39.png
# Pindah ke validation: R-156.png
# Pindah ke validation: R-79.png
# Pindah ke validation: R-261.png
# Pindah ke validation: R-280.png
# Pindah ke validation: R-473.png
# Pindah ke validation: R-354.png
# Pindah ke validation: R-291.png
# Pindah ke validation: R-456.png
# Pindah ke validation: R-476.png
# Pindah ke validation: R-234.png
# Pindah ke validation: R-332.png
# Pindah ke validation: R-259.png
# Pindah ke validation: R-360.png
# Pindah ke validation: R-342.png
# Pindah ke validation: R-329.png
# Pindah ke validation: R-292.png
# Pindah ke validation: R-186.png
# Pindah ke validation: R-373.png
# Pindah ke validation: R-187.png
# Pindah ke validation: R-455.png
# Pindah ke validation: R-389.png
# Pindah ke validation: R-201.png
# Pindah ke validation: R-117.png
# Pindah ke validation: R-233.png
# Pindah ke validation: R-202.png
# Pindah ke validation: R-63.png
# Pindah ke validation: R-321.png
# Pindah ke validation: R-446.png
# Pindah ke validation: R-124.png
# Pindah ke validation: R-442.png
# Pindah ke validation: R-210.png
# Pindah ke validation: R-98.png
# Pindah ke validation: R-70.png
# Pindah ke validation: R-375.png
# Pindah ke validation: R-424.png
# Pindah ke validation: R-356.png
# Pindah ke validation: R-411.png
# Pindah ke validation: R-405.png
# Pindah ke validation: R-390.png
# Pindah ke validation: R-184.png
# Pindah ke validation: R-103.png
# Pindah ke validation: R-431.png
# Pindah ke validation: R-126.png
# Pindah ke validation: R-173.png
# Pindah ke validation: R-206.png
# Pindah ke validation: R-26.png
# Pindah ke validation: R-35.png
# Pindah ke validation: R-203.png
# Pindah ke validation: R-244.png
# Pindah ke validation: R-209.png
# Pindah ke validation: R-440.png
# Pindah ke validation: R-388.png
# Pindah ke validation: R-93.png
# Pindah ke validation: R-116.png
# Pindah ke validation: R-327.png
# Pindah ke validation: R-392.png
# Pindah ke validation: R-107.png
# Pindah ke validation: R-316.png
# Pindah ke validation: R-118.png
# Pindah ke validation: R-296.png
# Pindah ke validation: R-132.png
# Pindah ke validation: R-68.png
# Pindah ke validation: R-346.png
# Pindah ke validation: R-216.png
# Pindah ke validation: R-288.png
# Pindah ke validation: R-454.png
# Pindah ke validation: R-19.png
# Pindah ke validation: R-421.png
# Pindah ke validation: R-344.png
# Pindah ke validation: R-365.png
# Pindah ke validation: R-157.png
# Pindah ke validation: R-263.png
# Huruf R: total=454, train=181, val=90, test=183
# Pindah ke train: S-3299.png
# Pindah ke train: S-3208.png
# Pindah ke train: S-3086.png
# Pindah ke train: S-3172.png
# Pindah ke train: S-3284.png
# Pindah ke train: S-3079.png
# Pindah ke train: S-3107.png
# Pindah ke train: S-3326.png
# Pindah ke train: S-3272.png
# Pindah ke train: S-3360.png
# Pindah ke train: S-3367.png
# Pindah ke train: S-3343.png
# Pindah ke train: S-3309.png
# Pindah ke train: S-3348.png
# Pindah ke train: S-3227.png
# Pindah ke train: S-3128.png
# Pindah ke train: S-3045.png
# Pindah ke train: S-3037.png
# Pindah ke train: S-3196.png
# Pindah ke train: S-3058.png
# Pindah ke train: S-3267.png
# Pindah ke train: S-3142.png
# Pindah ke train: S-3012.png
# Pindah ke train: S-3072.png
# Pindah ke train: S-3096.png
# Pindah ke train: S-3386.png
# Pindah ke train: S-3328.png
# Pindah ke train: S-3168.png
# Pindah ke train: S-3194.png
# Pindah ke train: S-3048.png
# Pindah ke train: S-3160.png
# Pindah ke train: S-3338.png
# Pindah ke train: S-3277.png
# Pindah ke train: S-3117.png
# Pindah ke train: S-3298.png
# Pindah ke train: S-3084.png
# Pindah ke train: S-3221.png
# Pindah ke train: S-3065.png
# Pindah ke train: S-3004.png
# Pindah ke train: S-3387.png
# Pindah ke train: S-3235.png
# Pindah ke train: S-3167.png
# Pindah ke train: S-3382.png
# Pindah ke train: S-3164.png
# Pindah ke train: S-3286.png
# Pindah ke train: S-3106.png
# Pindah ke train: S-3153.png
# Pindah ke train: S-3275.png
# Pindah ke train: S-3389.png
# Pindah ke train: S-3136.png
# Pindah ke train: S-3001.png
# Pindah ke train: S-3228.png
# Pindah ke train: S-3344.png
# Pindah ke train: S-3289.png
# Pindah ke train: S-3342.png
# Pindah ke train: S-3346.png
# Pindah ke train: S-3388.png
# Pindah ke train: S-3118.png
# Pindah ke train: S-3352.png
# Pindah ke train: S-3152.png
# Pindah ke train: S-3049.png
# Pindah ke train: S-3085.png
# Pindah ke train: S-3133.png
# Pindah ke train: S-3246.png
# Pindah ke train: S-3175.png
# Pindah ke train: S-3003.png
# Pindah ke train: S-3005.png
# Pindah ke train: S-3319.png
# Pindah ke train: S-3077.png
# Pindah ke train: S-3224.png
# Pindah ke train: S-3104.png
# Pindah ke train: S-3177.png
# Pindah ke train: S-3124.png
# Pindah ke train: S-3250.png
# Pindah ke train: S-3349.png
# Pindah ke train: S-3362.png
# Pindah ke train: S-3134.png
# Pindah ke train: S-3100.png
# Pindah ke train: S-3025.png
# Pindah ke train: S-3312.png
# Pindah ke train: S-3222.png
# Pindah ke train: S-3215.png
# Pindah ke train: S-3220.png
# Pindah ke train: S-3322.png
# Pindah ke train: S-3028.png
# Pindah ke train: S-3380.png
# Pindah ke train: S-3253.png
# Pindah ke train: S-3248.png
# Pindah ke train: S-3038.png
# Pindah ke train: S-3181.png
# Pindah ke train: S-3273.png
# Pindah ke train: S-3015.png
# Pindah ke train: S-3335.png
# Pindah ke train: S-3064.png
# Pindah ke train: S-3055.png
# Pindah ke train: S-3226.png
# Pindah ke train: S-3023.png
# Pindah ke train: S-3233.png
# Pindah ke train: S-3148.png
# Pindah ke train: S-3217.png
# Pindah ke train: S-3174.png
# Pindah ke train: S-3244.png
# Pindah ke train: S-3190.png
# Pindah ke train: S-3162.png
# Pindah ke train: S-3087.png
# Pindah ke train: S-3059.png
# Pindah ke train: S-3137.png
# Pindah ke train: S-3218.png
# Pindah ke train: S-3238.png
# Pindah ke train: S-3141.png
# Pindah ke train: S-3293.png
# Pindah ke train: S-3358.png
# Pindah ke train: S-3276.png
# Pindah ke train: S-3105.png
# Pindah ke train: S-3116.png
# Pindah ke train: S-3206.png
# Pindah ke train: S-3052.png
# Pindah ke train: S-3211.png
# Pindah ke train: S-3061.png
# Pindah ke train: S-3144.png
# Pindah ke train: S-3091.png
# Pindah ke train: S-3375.png
# Pindah ke train: S-3187.png
# Pindah ke train: S-3189.png
# Pindah ke train: S-3011.png
# Pindah ke train: S-3282.png
# Pindah ke train: S-3232.png
# Pindah ke train: S-3033.png
# Pindah ke train: S-3119.png
# Pindah ke train: S-3317.png
# Pindah ke train: S-3308.png
# Pindah ke train: S-3296.png
# Pindah ke train: S-3126.png
# Pindah ke train: S-3195.png
# Pindah ke train: S-3179.png
# Pindah ke train: S-3159.png
# Pindah ke train: S-3201.png
# Pindah ke train: S-3057.png
# Pindah ke train: S-3130.png
# Pindah ke train: S-3192.png
# Pindah ke train: S-3151.png
# Pindah ke train: S-3252.png
# Pindah ke train: S-3355.png
# Pindah ke train: S-3371.png
# Pindah ke train: S-3138.png
# Pindah ke train: S-3140.png
# Pindah ke train: S-3016.png
# Pindah ke train: S-3088.png
# Pindah ke train: S-3081.png
# Pindah ke train: S-3354.png
# Pindah ke train: S-3341.png
# Pindah ke train: S-3044.png
# Pindah ke train: S-3185.png
# Pindah ke train: S-3271.png
# Pindah ke train: S-3301.png
# Pindah ke train: S-3031.png
# Pindah ke train: S-3051.png
# Pindah ke train: S-3125.png
# Pindah ke train: S-3329.png
# Pindah ke train: S-3156.png
# Pindah ke validation: S-3054.png
# Pindah ke validation: S-3395.png
# Pindah ke validation: S-3066.png
# Pindah ke validation: S-3067.png
# Pindah ke validation: S-3030.png
# Pindah ke validation: S-3143.png
# Pindah ke validation: S-3099.png
# Pindah ke validation: S-3251.png
# Pindah ke validation: S-3127.png
# Pindah ke validation: S-3047.png
# Pindah ke validation: S-3006.png
# Pindah ke validation: S-3029.png
# Pindah ke validation: S-3264.png
# Pindah ke validation: S-3374.png
# Pindah ke validation: S-3166.png
# Pindah ke validation: S-3080.png
# Pindah ke validation: S-3101.png
# Pindah ke validation: S-3193.png
# Pindah ke validation: S-3135.png
# Pindah ke validation: S-3035.png
# Pindah ke validation: S-3364.png
# Pindah ke validation: S-3321.png
# Pindah ke validation: S-3260.png
# Pindah ke validation: S-3384.png
# Pindah ke validation: S-3337.png
# Pindah ke validation: S-3115.png
# Pindah ke validation: S-3200.png
# Pindah ke validation: S-3039.png
# Pindah ke validation: S-3399.png
# Pindah ke validation: S-3306.png
# Pindah ke validation: S-3401.png
# Pindah ke validation: S-3098.png
# Pindah ke validation: S-3092.png
# Pindah ke validation: S-3209.png
# Pindah ke validation: S-3165.png
# Pindah ke validation: S-3060.png
# Pindah ke validation: S-3017.png
# Pindah ke validation: S-3285.png
# Pindah ke validation: S-3303.png
# Pindah ke validation: S-3112.png
# Pindah ke validation: S-3207.png
# Pindah ke validation: S-3155.png
# Pindah ke validation: S-3036.png
# Pindah ke validation: S-3007.png
# Pindah ke validation: S-3359.png
# Pindah ke validation: S-3258.png
# Pindah ke validation: S-3336.png
# Pindah ke validation: S-3249.png
# Pindah ke validation: S-3357.png
# Pindah ke validation: S-3287.png
# Pindah ke validation: S-3281.png
# Pindah ke validation: S-3351.png
# Pindah ke validation: S-3372.png
# Pindah ke validation: S-3369.png
# Pindah ke validation: S-3377.png
# Pindah ke validation: S-3385.png
# Pindah ke validation: S-3376.png
# Pindah ke validation: S-3370.png
# Pindah ke validation: S-3111.png
# Pindah ke validation: S-3157.png
# Pindah ke validation: S-3090.png
# Pindah ke validation: S-3247.png
# Pindah ke validation: S-3310.png
# Pindah ke validation: S-3231.png
# Pindah ke validation: S-3290.png
# Pindah ke validation: S-3391.png
# Pindah ke validation: S-3300.png
# Pindah ke validation: S-3400.png
# Pindah ke validation: S-3109.png
# Pindah ke validation: S-3183.png
# Pindah ke validation: S-3243.png
# Pindah ke validation: S-3378.png
# Pindah ke validation: S-3078.png
# Pindah ke validation: S-3239.png
# Pindah ke validation: S-3266.png
# Pindah ke validation: S-3083.png
# Pindah ke validation: S-3288.png
# Pindah ke validation: S-3026.png
# Pindah ke validation: S-3398.png
# Pindah ke validation: S-3394.png
# Huruf S: total=402, train=160, val=80, test=162
# Pindah ke train: T-296.png
# Pindah ke train: T-128.png
# Pindah ke train: T-494.png
# Pindah ke train: T-238.png
# Pindah ke train: T-64.png
# Pindah ke train: T-400.png
# Pindah ke train: T-74.png
# Pindah ke train: T-87.png
# Pindah ke train: T-225.png
# Pindah ke train: T-393.png
# Pindah ke train: T-416.png
# Pindah ke train: T-307.png
# Pindah ke train: T-369.png
# Pindah ke train: T-18.png
# Pindah ke train: T-88.png
# Pindah ke train: T-264.png
# Pindah ke train: T-348.png
# Pindah ke train: T-493.png
# Pindah ke train: T-114.png
# Pindah ke train: T-336.png
# Pindah ke train: T-465.png
# Pindah ke train: T-324.png
# Pindah ke train: T-26.png
# Pindah ke train: T-423.png
# Pindah ke train: T-388.png
# Pindah ke train: T-334.png
# Pindah ke train: T-405.png
# Pindah ke train: T-215.png
# Pindah ke train: T-43.png
# Pindah ke train: T-241.png
# Pindah ke train: T-7.png
# Pindah ke train: T-279.png
# Pindah ke train: T-310.png
# Pindah ke train: T-156.png
# Pindah ke train: T-195.png
# Pindah ke train: T-103.png
# Pindah ke train: T-212.png
# Pindah ke train: T-431.png
# Pindah ke train: T-210.png
# Pindah ke train: T-153.png
# Pindah ke train: T-311.png
# Pindah ke train: T-207.png
# Pindah ke train: T-435.png
# Pindah ke train: T-5.png
# Pindah ke train: T-325.png
# Pindah ke train: T-109.png
# Pindah ke train: T-339.png
# Pindah ke train: T-189.png
# Pindah ke train: T-159.png
# Pindah ke train: T-20.png
# Pindah ke train: T-275.png
# Pindah ke train: T-8.png
# Pindah ke train: T-91.png
# Pindah ke train: T-281.png
# Pindah ke train: T-368.png
# Pindah ke train: T-443.png
# Pindah ke train: T-233.png
# Pindah ke train: T-83.png
# Pindah ke train: T-137.png
# Pindah ke train: T-124.png
# Pindah ke train: T-496.png
# Pindah ke train: T-36.png
# Pindah ke train: T-475.png
# Pindah ke train: T-185.png
# Pindah ke train: T-218.png
# Pindah ke train: T-79.png
# Pindah ke train: T-39.png
# Pindah ke train: T-266.png
# Pindah ke train: T-217.png
# Pindah ke train: T-179.png
# Pindah ke train: T-394.png
# Pindah ke train: T-341.png
# Pindah ke train: T-107.png
# Pindah ke train: T-182.png
# Pindah ke train: T-302.png
# Pindah ke train: T-453.png
# Pindah ke train: T-141.png
# Pindah ke train: T-262.png
# Pindah ke train: T-196.png
# Pindah ke train: T-113.png
# Pindah ke train: T-469.png
# Pindah ke train: T-145.png
# Pindah ke train: T-130.png
# Pindah ke train: T-65.png
# Pindah ke train: T-62.png
# Pindah ke train: T-392.png
# Pindah ke train: T-193.png
# Pindah ke train: T-437.png
# Pindah ke train: T-441.png
# Pindah ke train: T-274.png
# Pindah ke train: T-147.png
# Pindah ke train: T-102.png
# Pindah ke train: T-304.png
# Pindah ke train: T-243.png
# Pindah ke train: T-491.png
# Pindah ke train: T-25.png
# Pindah ke train: T-0.png
# Pindah ke train: T-127.png
# Pindah ke train: T-143.png
# Pindah ke train: T-458.png
# Pindah ke train: T-85.png
# Pindah ke train: T-363.png
# Pindah ke train: T-278.png
# Pindah ke train: T-151.png
# Pindah ke train: T-459.png
# Pindah ke train: T-2.png
# Pindah ke train: T-299.png
# Pindah ke train: T-199.png
# Pindah ke train: T-146.png
# Pindah ke train: T-448.png
# Pindah ke train: T-414.png
# Pindah ke train: T-150.png
# Pindah ke train: T-104.png
# Pindah ke train: T-240.png
# Pindah ke train: T-15.png
# Pindah ke train: T-282.png
# Pindah ke train: T-354.png
# Pindah ke train: T-84.png
# Pindah ke train: T-37.png
# Pindah ke train: T-306.png
# Pindah ke train: T-180.png
# Pindah ke train: T-344.png
# Pindah ke train: T-421.png
# Pindah ke train: T-110.png
# Pindah ke train: T-234.png
# Pindah ke train: T-397.png
# Pindah ke train: T-73.png
# Pindah ke train: T-347.png
# Pindah ke train: T-136.png
# Pindah ke train: T-132.png
# Pindah ke train: T-420.png
# Pindah ke train: T-292.png
# Pindah ke train: T-321.png
# Pindah ke train: T-404.png
# Pindah ke train: T-468.png
# Pindah ke train: T-471.png
# Pindah ke train: T-387.png
# Pindah ke train: T-488.png
# Pindah ke train: T-295.png
# Pindah ke train: T-47.png
# Pindah ke train: T-95.png
# Pindah ke train: T-350.png
# Pindah ke train: T-221.png
# Pindah ke train: T-206.png
# Pindah ke train: T-490.png
# Pindah ke train: T-398.png
# Pindah ke train: T-184.png
# Pindah ke train: T-298.png
# Pindah ke train: T-133.png
# Pindah ke train: T-77.png
# Pindah ke train: T-293.png
# Pindah ke train: T-379.png
# Pindah ke train: T-412.png
# Pindah ke train: T-183.png
# Pindah ke train: T-277.png
# Pindah ke train: T-375.png
# Pindah ke train: T-17.png
# Pindah ke train: T-213.png
# Pindah ke train: T-27.png
# Pindah ke train: T-51.png
# Pindah ke train: T-169.png
# Pindah ke train: T-312.png
# Pindah ke train: T-33.png
# Pindah ke train: T-111.png
# Pindah ke train: T-255.png
# Pindah ke train: T-181.png
# Pindah ke train: T-466.png
# Pindah ke train: T-303.png
# Pindah ke train: T-492.png
# Pindah ke train: T-232.png
# Pindah ke train: T-407.png
# Pindah ke train: T-287.png
# Pindah ke train: T-61.png
# Pindah ke train: T-200.png
# Pindah ke train: T-484.png
# Pindah ke train: T-419.png
# Pindah ke train: T-158.png
# Pindah ke train: T-1.png
# Pindah ke train: T-155.png
# Pindah ke train: T-172.png
# Pindah ke train: T-42.png
# Pindah ke train: T-13.png
# Pindah ke train: T-366.png
# Pindah ke train: T-76.png
# Pindah ke train: T-252.png
# Pindah ke train: T-333.png
# Pindah ke train: T-118.png
# Pindah ke train: T-455.png
# Pindah ke train: T-444.png
# Pindah ke train: T-372.png
# Pindah ke train: T-381.png
# Pindah ke train: T-456.png
# Pindah ke train: T-239.png
# Pindah ke train: T-32.png
# Pindah ke train: T-29.png
# Pindah ke train: T-272.png
# Pindah ke train: T-92.png
# Pindah ke train: T-359.png
# Pindah ke train: T-417.png
# Pindah ke validation: T-176.png
# Pindah ke validation: T-440.png
# Pindah ke validation: T-100.png
# Pindah ke validation: T-80.png
# Pindah ke validation: T-263.png
# Pindah ke validation: T-483.png
# Pindah ke validation: T-247.png
# Pindah ke validation: T-203.png
# Pindah ke validation: T-477.png
# Pindah ke validation: T-135.png
# Pindah ke validation: T-174.png
# Pindah ke validation: T-123.png
# Pindah ke validation: T-285.png
# Pindah ke validation: T-482.png
# Pindah ke validation: T-160.png
# Pindah ke validation: T-66.png
# Pindah ke validation: T-214.png
# Pindah ke validation: T-129.png
# Pindah ke validation: T-68.png
# Pindah ke validation: T-219.png
# Pindah ke validation: T-352.png
# Pindah ke validation: T-449.png
# Pindah ke validation: T-425.png
# Pindah ke validation: T-163.png
# Pindah ke validation: T-175.png
# Pindah ke validation: T-122.png
# Pindah ke validation: T-237.png
# Pindah ke validation: T-229.png
# Pindah ke validation: T-461.png
# Pindah ke validation: T-338.png
# Pindah ke validation: T-395.png
# Pindah ke validation: T-30.png
# Pindah ke validation: T-426.png
# Pindah ke validation: T-3.png
# Pindah ke validation: T-480.png
# Pindah ke validation: T-140.png
# Pindah ke validation: T-383.png
# Pindah ke validation: T-454.png
# Pindah ke validation: T-474.png
# Pindah ke validation: T-46.png
# Pindah ke validation: T-322.png
# Pindah ke validation: T-385.png
# Pindah ke validation: T-99.png
# Pindah ke validation: T-403.png
# Pindah ke validation: T-452.png
# Pindah ke validation: T-41.png
# Pindah ke validation: T-377.png
# Pindah ke validation: T-138.png
# Pindah ke validation: T-391.png
# Pindah ke validation: T-462.png
# Pindah ke validation: T-410.png
# Pindah ke validation: T-89.png
# Pindah ke validation: T-294.png
# Pindah ke validation: T-497.png
# Pindah ke validation: T-269.png
# Pindah ke validation: T-220.png
# Pindah ke validation: T-204.png
# Pindah ke validation: T-139.png
# Pindah ke validation: T-125.png
# Pindah ke validation: T-67.png
# Pindah ke validation: T-246.png
# Pindah ke validation: T-361.png
# Pindah ke validation: T-190.png
# Pindah ke validation: T-396.png
# Pindah ke validation: T-442.png
# Pindah ke validation: T-286.png
# Pindah ke validation: T-170.png
# Pindah ke validation: T-10.png
# Pindah ke validation: T-49.png
# Pindah ke validation: T-390.png
# Pindah ke validation: T-401.png
# Pindah ke validation: T-44.png
# Pindah ke validation: T-406.png
# Pindah ke validation: T-144.png
# Pindah ke validation: T-445.png
# Pindah ke validation: T-205.png
# Pindah ke validation: T-70.png
# ...
# Pindah ke validation: X-260.png
# Pindah ke validation: X-100.png
# Pindah ke validation: X-170.png
# Pindah ke validation: X-249.png
# Pindah ke validation: X-85.png
# Pindah ke validation: X-112.png
# Pindah ke validation: X-57.png
# Pindah ke validation: X-356.png
# Pindah ke validation: X-394.png
# Pindah ke validation: X-312.png
# Pindah ke validation: X-21.png
# Pindah ke validation: X-303.png
# Pindah ke validation: X-349.png
# Pindah ke validation: X-266.png
# Pindah ke validation: X-384.png
# Pindah ke validation: X-82.png
# Pindah ke validation: X-99.png
# Pindah ke validation: X-74.png
# Pindah ke validation: X-180.png
# Pindah ke validation: X-278.png
# Pindah ke validation: X-95.png
# Pindah ke validation: X-80.png
# Pindah ke validation: X-357.png
# Pindah ke validation: X-2.png
# Pindah ke validation: X-254.png
# Pindah ke validation: X-229.png
# Pindah ke validation: X-283.png
# Pindah ke validation: X-209.png
# Pindah ke validation: X-368.png
# Pindah ke validation: X-366.png
# Pindah ke validation: X-121.png
# Pindah ke validation: X-134.png
# Pindah ke validation: X-293.png
# Pindah ke validation: X-111.png
# Pindah ke validation: X-265.png
# Pindah ke validation: X-259.png
# Pindah ke validation: X-79.png
# Pindah ke validation: X-123.png
# Pindah ke validation: X-136.png
# Pindah ke validation: X-318.png
# Pindah ke validation: X-301.png
# Pindah ke validation: X-248.png
# Huruf X: total=405, train=162, val=81, test=162
# Pindah ke train: Y-393.png
# Pindah ke train: Y-82.png
# Pindah ke train: Y-162.png
# Pindah ke train: Y-76.png
# Pindah ke train: Y-407.png
# Pindah ke train: Y-307.png
# Pindah ke train: Y-30.png
# Pindah ke train: Y-198.png
# Pindah ke train: Y-34.png
# Pindah ke train: Y-39.png
# Pindah ke train: Y-63.png
# Pindah ke train: Y-203.png
# Pindah ke train: Y-320.png
# Pindah ke train: Y-164.png
# Pindah ke train: Y-291.png
# Pindah ke train: Y-102.png
# Pindah ke train: Y-97.png
# Pindah ke train: Y-3.png
# Pindah ke train: Y-410.png
# Pindah ke train: Y-0.png
# Pindah ke train: Y-177.png
# Pindah ke train: Y-421.png
# Pindah ke train: Y-111.png
# Pindah ke train: Y-295.png
# Pindah ke train: Y-382.png
# Pindah ke train: Y-419.png
# Pindah ke train: Y-379.png
# Pindah ke train: Y-297.png
# Pindah ke train: Y-409.png
# Pindah ke train: Y-105.png
# Pindah ke train: Y-431.png
# Pindah ke train: Y-219.png
# Pindah ke train: Y-315.png
# Pindah ke train: Y-313.png
# Pindah ke train: Y-179.png
# Pindah ke train: Y-342.png
# Pindah ke train: Y-260.png
# Pindah ke train: Y-205.png
# Pindah ke train: Y-422.png
# Pindah ke train: Y-437.png
# Pindah ke train: Y-392.png
# Pindah ke train: Y-53.png
# Pindah ke train: Y-159.png
# Pindah ke train: Y-390.png
# Pindah ke train: Y-416.png
# Pindah ke train: Y-289.png
# Pindah ke train: Y-406.png
# Pindah ke train: Y-360.png
# Pindah ke train: Y-60.png
# Pindah ke train: Y-148.png
# Pindah ke train: Y-364.png
# Pindah ke train: Y-425.png
# Pindah ke train: Y-357.png
# Pindah ke train: Y-439.png
# Pindah ke train: Y-372.png
# Pindah ke train: Y-119.png
# Pindah ke train: Y-318.png
# Pindah ke train: Y-4.png
# Pindah ke train: Y-36.png
# Pindah ke train: Y-275.png
# Pindah ke train: Y-141.png
# Pindah ke train: Y-110.png
# Pindah ke train: Y-50.png
# Pindah ke train: Y-211.png
# Pindah ke train: Y-428.png
# Pindah ke train: Y-321.png
# Pindah ke train: Y-206.png
# Pindah ke train: Y-375.png
# Pindah ke train: Y-15.png
# Pindah ke train: Y-319.png
# Pindah ke train: Y-64.png
# Pindah ke train: Y-442.png
# Pindah ke train: Y-324.png
# Pindah ke train: Y-222.png
# Pindah ke train: Y-415.png
# Pindah ke train: Y-176.png
# Pindah ke train: Y-93.png
# Pindah ke train: Y-314.png
# Pindah ke train: Y-157.png
# Pindah ke train: Y-95.png
# Pindah ke train: Y-151.png
# Pindah ke train: Y-300.png
# Pindah ke train: Y-399.png
# Pindah ke train: Y-185.png
# Pindah ke train: Y-96.png
# Pindah ke train: Y-241.png
# Pindah ke train: Y-252.png
# Pindah ke train: Y-340.png
# Pindah ke train: Y-173.png
# Pindah ke train: Y-236.png
# Pindah ke train: Y-434.png
# Pindah ke train: Y-160.png
# Pindah ke train: Y-212.png
# Pindah ke train: Y-214.png
# Pindah ke train: Y-327.png
# Pindah ke train: Y-309.png
# Pindah ke train: Y-287.png
# Pindah ke train: Y-144.png
# Pindah ke train: Y-210.png
# Pindah ke train: Y-245.png
# Pindah ke train: Y-404.png
# Pindah ke train: Y-66.png
# Pindah ke train: Y-243.png
# Pindah ke train: Y-279.png
# Pindah ke train: Y-194.png
# Pindah ke train: Y-196.png
# Pindah ke train: Y-106.png
# Pindah ke train: Y-316.png
# Pindah ke train: Y-397.png
# Pindah ke train: Y-351.png
# Pindah ke train: Y-271.png
# Pindah ke train: Y-16.png
# Pindah ke train: Y-5.png
# Pindah ke train: Y-262.png
# Pindah ke train: Y-248.png
# Pindah ke train: Y-13.png
# Pindah ke train: Y-440.png
# Pindah ke train: Y-49.png
# Pindah ke train: Y-330.png
# Pindah ke train: Y-420.png
# Pindah ke train: Y-65.png
# Pindah ke train: Y-329.png
# Pindah ke train: Y-218.png
# Pindah ke train: Y-154.png
# Pindah ke train: Y-227.png
# Pindah ke train: Y-326.png
# Pindah ke train: Y-139.png
# Pindah ke train: Y-71.png
# Pindah ke train: Y-249.png
# Pindah ke train: Y-208.png
# Pindah ke train: Y-251.png
# Pindah ke train: Y-292.png
# Pindah ke train: Y-181.png
# Pindah ke train: Y-161.png
# Pindah ke train: Y-384.png
# Pindah ke train: Y-257.png
# Pindah ke train: Y-155.png
# Pindah ke train: Y-68.png
# Pindah ke train: Y-273.png
# Pindah ke train: Y-137.png
# Pindah ke train: Y-394.png
# Pindah ke train: Y-328.png
# Pindah ke train: Y-182.png
# Pindah ke train: Y-133.png
# Pindah ke train: Y-267.png
# Pindah ke train: Y-239.png
# Pindah ke train: Y-48.png
# Pindah ke train: Y-77.png
# Pindah ke train: Y-396.png
# Pindah ke train: Y-283.png
# Pindah ke train: Y-332.png
# Pindah ke train: Y-302.png
# Pindah ke train: Y-56.png
# Pindah ke train: Y-152.png
# Pindah ke train: Y-127.png
# Pindah ke train: Y-310.png
# Pindah ke train: Y-174.png
# Pindah ke train: Y-376.png
# Pindah ke train: Y-231.png
# Pindah ke train: Y-143.png
# Pindah ke train: Y-120.png
# Pindah ke train: Y-255.png
# Pindah ke train: Y-113.png
# Pindah ke train: Y-308.png
# Pindah ke train: Y-311.png
# Pindah ke train: Y-25.png
# Pindah ke train: Y-261.png
# Pindah ke train: Y-204.png
# Pindah ke train: Y-269.png
# Pindah ke train: Y-11.png
# Pindah ke train: Y-229.png
# Pindah ke train: Y-14.png
# Pindah ke train: Y-124.png
# Pindah ke train: Y-356.png
# Pindah ke train: Y-156.png
# Pindah ke train: Y-24.png
# Pindah ke train: Y-293.png
# Pindah ke validation: Y-81.png
# Pindah ke validation: Y-135.png
# Pindah ke validation: Y-371.png
# Pindah ke validation: Y-52.png
# Pindah ke validation: Y-280.png
# Pindah ke validation: Y-354.png
# Pindah ke validation: Y-147.png
# Pindah ke validation: Y-43.png
# Pindah ke validation: Y-265.png
# Pindah ke validation: Y-37.png
# Pindah ke validation: Y-344.png
# Pindah ke validation: Y-117.png
# Pindah ke validation: Y-224.png
# Pindah ke validation: Y-221.png
# Pindah ke validation: Y-58.png
# Pindah ke validation: Y-235.png
# Pindah ke validation: Y-90.png
# Pindah ke validation: Y-322.png
# Pindah ke validation: Y-107.png
# Pindah ke validation: Y-86.png
# Pindah ke validation: Y-33.png
# Pindah ke validation: Y-424.png
# Pindah ke validation: Y-225.png
# Pindah ke validation: Y-92.png
# Pindah ke validation: Y-430.png
# Pindah ke validation: Y-412.png
# Pindah ke validation: Y-266.png
# Pindah ke validation: Y-395.png
# Pindah ke validation: Y-254.png
# Pindah ke validation: Y-167.png
# Pindah ke validation: Y-335.png
# Pindah ke validation: Y-401.png
# Pindah ke validation: Y-166.png
# Pindah ke validation: Y-223.png
# Pindah ke validation: Y-282.png
# Pindah ke validation: Y-281.png
# Pindah ke validation: Y-438.png
# Pindah ke validation: Y-366.png
# Pindah ke validation: Y-443.png
# Pindah ke validation: Y-149.png
# Pindah ke validation: Y-362.png
# Pindah ke validation: Y-134.png
# Pindah ke validation: Y-67.png
# Pindah ke validation: Y-104.png
# Pindah ke validation: Y-400.png
# Pindah ke validation: Y-288.png
# Pindah ke validation: Y-19.png
# Pindah ke validation: Y-186.png
# Pindah ke validation: Y-40.png
# Pindah ke validation: Y-373.png
# Pindah ke validation: Y-163.png
# Pindah ke validation: Y-361.png
# Pindah ke validation: Y-238.png
# Pindah ke validation: Y-168.png
# Pindah ke validation: Y-256.png
# Pindah ke validation: Y-28.png
# Pindah ke validation: Y-88.png
# Pindah ke validation: Y-338.png
# Pindah ke validation: Y-381.png
# Pindah ke validation: Y-367.png
# Pindah ke validation: Y-114.png
# Pindah ke validation: Y-80.png
# Pindah ke validation: Y-26.png
# Pindah ke validation: Y-108.png
# Pindah ke validation: Y-232.png
# Pindah ke validation: Y-27.png
# Pindah ke validation: Y-427.png
# Pindah ke validation: Y-8.png
# Pindah ke validation: Y-240.png
# Pindah ke validation: Y-386.png
# Pindah ke validation: Y-359.png
# Pindah ke validation: Y-1.png
# Pindah ke validation: Y-94.png
# Pindah ke validation: Y-125.png
# Pindah ke validation: Y-253.png
# Pindah ke validation: Y-436.png
# Pindah ke validation: Y-380.png
# Pindah ke validation: Y-170.png
# Pindah ke validation: Y-298.png
# Pindah ke validation: Y-285.png
# Pindah ke validation: Y-305.png
# Pindah ke validation: Y-59.png
# Pindah ke validation: Y-286.png
# Pindah ke validation: Y-217.png
# Pindah ke validation: Y-202.png
# Pindah ke validation: Y-55.png
# Pindah ke validation: Y-51.png
# Pindah ke validation: Y-180.png
# Huruf Y: total=443, train=177, val=88, test=178
# Pindah ke train: Z-239.png
# Pindah ke train: Z-133.png
# Pindah ke train: Z-62.png
# Pindah ke train: Z-231.png
# Pindah ke train: Z-321.png
# Pindah ke train: Z-173.png
# Pindah ke train: Z-117.png
# Pindah ke train: Z-101.png
# Pindah ke train: Z-327.png
# Pindah ke train: Z-96.png
# Pindah ke train: Z-396.png
# Pindah ke train: Z-326.png
# Pindah ke train: Z-146.png
# Pindah ke train: Z-27.png
# Pindah ke train: Z-204.png
# Pindah ke train: Z-3.png
# Pindah ke train: Z-77.png
# Pindah ke train: Z-109.png
# Pindah ke train: Z-4.png
# Pindah ke train: Z-241.png
# Pindah ke train: Z-165.png
# Pindah ke train: Z-210.png
# Pindah ke train: Z-132.png
# Pindah ke train: Z-86.png
# Pindah ke train: Z-222.png
# Pindah ke train: Z-299.png
# Pindah ke train: Z-168.png
# Pindah ke train: Z-170.png
# Pindah ke train: Z-169.png
# Pindah ke train: Z-270.png
# Pindah ke train: Z-282.png
# Pindah ke train: Z-264.png
# Pindah ke train: Z-162.png
# Pindah ke train: Z-30.png
# Pindah ke train: Z-240.png
# Pindah ke train: Z-310.png
# Pindah ke train: Z-103.png
# Pindah ke train: Z-266.png
# Pindah ke train: Z-81.png
# Pindah ke train: Z-303.png
# Pindah ke train: Z-23.png
# Pindah ke train: Z-379.png
# Pindah ke train: Z-14.png
# Pindah ke train: Z-35.png
# Pindah ke train: Z-45.png
# Pindah ke train: Z-268.png
# Pindah ke train: Z-49.png
# Pindah ke train: Z-196.png
# Pindah ke train: Z-360.png
# Pindah ke train: Z-174.png
# Pindah ke train: Z-331.png
# Pindah ke train: Z-127.png
# Pindah ke train: Z-280.png
# Pindah ke train: Z-350.png
# Pindah ke train: Z-47.png
# Pindah ke train: Z-212.png
# Pindah ke train: Z-91.png
# Pindah ke train: Z-53.png
# Pindah ke train: Z-258.png
# Pindah ke train: Z-275.png
# Pindah ke train: Z-197.png
# Pindah ke train: Z-141.png
# Pindah ke train: Z-286.png
# Pindah ke train: Z-368.png
# Pindah ke train: Z-201.png
# Pindah ke train: Z-226.png
# Pindah ke train: Z-298.png
# Pindah ke train: Z-220.png
# Pindah ke train: Z-44.png
# Pindah ke train: Z-394.png
# Pindah ke train: Z-31.png
# Pindah ke train: Z-384.png
# Pindah ke train: Z-54.png
# Pindah ke train: Z-102.png
# Pindah ke train: Z-160.png
# Pindah ke train: Z-263.png
# Pindah ke train: Z-71.png
# Pindah ke train: Z-107.png
# Pindah ke train: Z-111.png
# Pindah ke train: Z-311.png
# Pindah ke train: Z-388.png
# Pindah ke train: Z-7.png
# Pindah ke train: Z-346.png
# Pindah ke train: Z-63.png
# Pindah ke train: Z-351.png
# Pindah ke train: Z-207.png
# Pindah ke train: Z-121.png
# Pindah ke train: Z-301.png
# Pindah ke train: Z-223.png
# Pindah ke train: Z-125.png
# Pindah ke train: Z-322.png
# Pindah ke train: Z-155.png
# Pindah ke train: Z-12.png
# Pindah ke train: Z-361.png
# Pindah ke train: Z-98.png
# Pindah ke train: Z-129.png
# Pindah ke train: Z-97.png
# Pindah ke train: Z-255.png
# Pindah ke train: Z-99.png
# Pindah ke train: Z-369.png
# Pindah ke train: Z-329.png
# Pindah ke train: Z-261.png
# Pindah ke train: Z-309.png
# Pindah ke train: Z-341.png
# Pindah ke train: Z-335.png
# Pindah ke train: Z-184.png
# Pindah ke train: Z-247.png
# Pindah ke train: Z-254.png
# Pindah ke train: Z-87.png
# Pindah ke train: Z-130.png
# Pindah ke train: Z-126.png
# Pindah ke train: Z-128.png
# Pindah ke train: Z-194.png
# Pindah ke train: Z-208.png
# Pindah ke train: Z-242.png
# Pindah ke train: Z-366.png
# Pindah ke train: Z-234.png
# Pindah ke train: Z-139.png
# Pindah ke train: Z-145.png
# Pindah ke train: Z-305.png
# Pindah ke train: Z-325.png
# Pindah ke train: Z-273.png
# Pindah ke train: Z-246.png
# Pindah ke train: Z-94.png
# Pindah ke train: Z-75.png
# Pindah ke train: Z-189.png
# Pindah ke train: Z-171.png
# Pindah ke train: Z-186.png
# Pindah ke train: Z-251.png
# Pindah ke train: Z-237.png
# Pindah ke train: Z-228.png
# Pindah ke train: Z-340.png
# Pindah ke train: Z-104.png
# Pindah ke train: Z-219.png
# Pindah ke train: Z-328.png
# Pindah ke train: Z-364.png
# Pindah ke train: Z-154.png
# Pindah ke train: Z-209.png
# Pindah ke train: Z-69.png
# Pindah ke train: Z-20.png
# Pindah ke train: Z-156.png
# Pindah ke train: Z-221.png
# Pindah ke train: Z-84.png
# Pindah ke train: Z-359.png
# Pindah ke train: Z-124.png
# Pindah ke train: Z-59.png
# Pindah ke train: Z-76.png
# Pindah ke train: Z-213.png
# Pindah ke train: Z-114.png
# Pindah ke train: Z-248.png
# Pindah ke train: Z-122.png
# Pindah ke train: Z-50.png
# Pindah ke train: Z-355.png
# Pindah ke train: Z-284.png
# Pindah ke train: Z-382.png
# Pindah ke train: Z-308.png
# Pindah ke train: Z-230.png
# Pindah ke train: Z-313.png
# Pindah ke train: Z-202.png
# Pindah ke train: Z-41.png
# Pindah ke validation: Z-46.png
# Pindah ke validation: Z-15.png
# Pindah ke validation: Z-312.png
# Pindah ke validation: Z-178.png
# Pindah ke validation: Z-179.png
# Pindah ke validation: Z-232.png
# Pindah ke validation: Z-227.png
# Pindah ke validation: Z-163.png
# Pindah ke validation: Z-316.png
# Pindah ke validation: Z-306.png
# Pindah ke validation: Z-113.png
# Pindah ke validation: Z-352.png
# Pindah ke validation: Z-51.png
# Pindah ke validation: Z-92.png
# Pindah ke validation: Z-233.png
# Pindah ke validation: Z-398.png
# Pindah ke validation: Z-19.png
# Pindah ke validation: Z-252.png
# Pindah ke validation: Z-391.png
# Pindah ke validation: Z-377.png
# Pindah ke validation: Z-52.png
# Pindah ke validation: Z-300.png
# Pindah ke validation: Z-134.png
# Pindah ke validation: Z-38.png
# Pindah ke validation: Z-290.png
# Pindah ke validation: Z-153.png
# Pindah ke validation: Z-72.png
# Pindah ke validation: Z-345.png
# Pindah ke validation: Z-253.png
# Pindah ke validation: Z-64.png
# Pindah ke validation: Z-395.png
# Pindah ke validation: Z-151.png
# Pindah ke validation: Z-314.png
# Pindah ke validation: Z-278.png
# Pindah ke validation: Z-79.png
# Pindah ke validation: Z-302.png
# Pindah ke validation: Z-399.png
# Pindah ke validation: Z-68.png
# Pindah ke validation: Z-353.png
# Pindah ke validation: Z-73.png
# Pindah ke validation: Z-25.png
# Pindah ke validation: Z-144.png
# Pindah ke validation: Z-357.png
# Pindah ke validation: Z-58.png
# Pindah ke validation: Z-211.png
# Pindah ke validation: Z-245.png
# Pindah ke validation: Z-138.png
# Pindah ke validation: Z-277.png
# Pindah ke validation: Z-110.png
# Pindah ke validation: Z-235.png
# Pindah ke validation: Z-262.png
# Pindah ke validation: Z-55.png
# Pindah ke validation: Z-387.png
# Pindah ke validation: Z-249.png
# Pindah ke validation: Z-60.png
# Pindah ke validation: Z-82.png
# Pindah ke validation: Z-187.png
# Pindah ke validation: Z-348.png
# Pindah ke validation: Z-67.png
# Pindah ke validation: Z-238.png
# Pindah ke validation: Z-78.png
# Pindah ke validation: Z-183.png
# Pindah ke validation: Z-149.png
# Pindah ke validation: Z-40.png
# Pindah ke validation: Z-112.png
# Pindah ke validation: Z-8.png
# Pindah ke validation: Z-199.png
# Pindah ke validation: Z-236.png
# Pindah ke validation: Z-206.png
# Pindah ke validation: Z-131.png
# Pindah ke validation: Z-57.png
# Pindah ke validation: Z-119.png
# Pindah ke validation: Z-324.png
# Pindah ke validation: Z-1.png
# Pindah ke validation: Z-244.png
# Pindah ke validation: Z-188.png
# Pindah ke validation: Z-323.png
# Pindah ke validation: Z-11.png
# Pindah ke validation: Z-260.png
# Pindah ke validation: Z-48.png
# Huruf Z: total=400, train=160, val=80, test=160
#
# Selesai.
# Total dipindah ke train: 2354 file
# Total dipindah ke validation: 1175 file
# Folder validation/Normal telah dibuat di: Dataset/Gambo\Validation\Normal

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

CSV_INPUT = 'master_dataset_dyslexia.csv'
CSV_OUTPUT = 'master_dataset_final.csv'
TRAIN_RATIO, VAL_RATIO, TEST_RATIO = 0.70, 0.15, 0.15

# Load
df = pd.read_csv(CSV_INPUT)
print(f'Total data awal: {len(df):,} baris')

# 1) Buat ID unik berdasarkan path asli (tanpa ubah gambar asli)
#    Ambil nama folder induk dari image_path (mis. "Test" atau "Train")
#    Asumsi format path: "Dataset\Gambo\[induk]\[sub_folder]\nama_file.png"
#    Kita ambil [induk] sebagai prefix
df['original_parent'] = df['image_path'].apply(lambda x: x.split('\\')[2])   # 'Test' / 'Train' / dll
df['unique_filename'] = df['original_parent'] + '_' + df['folder_category'] + '_' + df['file_name']

# Cek keunikan
print(f'Unique filenames: {df["unique_filename"].nunique()} / {len(df)}')

# 2) Stratified split berdasarkan severity_score (data sudah unik, tidak perlu drop_duplicates)
df_train_val, df_test = train_test_split(
    df,
    test_size=TEST_RATIO,
    random_state=42,
    stratify=df['severity_score']
)
val_ratio_of_train_val = VAL_RATIO / (TRAIN_RATIO + VAL_RATIO)
df_train, df_val = train_test_split(
    df_train_val,
    test_size=val_ratio_of_train_val,
    random_state=42,
    stratify=df_train_val['severity_score']
)

# 3) Set label split
df_train['split'] = 'Train'
df_val['split']   = 'Validation'
df_test['split']  = 'Test'

df_final = pd.concat([df_train, df_val, df_test], ignore_index=True)

# 4) Simpan (kolom unique_filename bisa dipakai untuk kopi gambar nanti)
df_final.to_csv(CSV_OUTPUT, index=False)

# Laporan
print(f'\n=== HASIL SPLIT STANDARD (70/15/15) ===')
for split in ['Train', 'Validation', 'Test']:
    n = len(df_final[df_final['split'] == split])
    print(f'{split:12s}: {n:>8,} gambar ({n/len(df_final)*100:5.1f}%)')

# Cek duplikasi nama unik di setiap split
for split in ['Train', 'Validation', 'Test']:
    subset = df_final[df_final['split'] == split]
    dup = subset['unique_filename'].duplicated().sum()
    if dup:
        print(f'⚠️ {split} masih ada {dup} nama file duplikat (harusnya 0)')
    else:
        print(f'✅ {split} tidak ada nama file duplikat')
# Out:
# Total data awal: 156,453 baris
# Unique filenames: 156453 / 156453
#
# === HASIL SPLIT STANDARD (70/15/15) ===
# Train       :  109,517 gambar ( 70.0%)
# Validation  :   23,468 gambar ( 15.0%)
# Test        :   23,468 gambar ( 15.0%)
# ✅ Train tidak ada nama file duplikat
# ✅ Validation tidak ada nama file duplikat
# ✅ Test tidak ada nama file duplikat

# %%
import os
import shutil
import pandas as pd

# ============================================================
# CONFIG
# ============================================================
CSV_PATH = 'master_dataset_final.csv'
OUTPUT_ROOT = r'Dataset/Gambo_Split'
COPY_MODE = True  # True = copy, False = move

# ============================================================
# LOAD CSV
# ============================================================
df = pd.read_csv(CSV_PATH)

print('=' * 60)
print('MEMUAT CSV')
print('=' * 60)
print(f'Total rows CSV : {len(df):,}')

# ============================================================
# CEK DUPLICATE TARGET (sekarang tidak masalah karena pakai subfolder)
# ============================================================
duplicate_rows = df.duplicated(subset=['split', 'folder_category', 'file_name']).sum()
print(f'Duplicate target filename (per split/category): {duplicate_rows:,}')
if duplicate_rows > 0:
    print('\n⚠ WARNING: Ada filename duplicate dalam split/category yang sama.')
    print('Akan disimpan dengan subfolder berdasarkan asal untuk menghindari bentrok.\n')

# ============================================================
# SUMMARY SPLIT
# ============================================================
print('=' * 60)
print('PROPORSI SPLIT')
print('=' * 60)
for split_name in ['Train', 'Validation', 'Test']:
    count = len(df[df['split'] == split_name])
    print(f'{split_name:12s}: {count:,}')

# ============================================================
# FUNGSI AMBIL ASAL FOLDER
# ============================================================
def get_origin_from_path(path):
    """Mengembalikan 'train_asli', 'test_asli', atau 'validation_asli' berdasarkan path."""
    if 'Train' in path or 'train' in path:
        return 'train_asli'
    elif 'Test' in path or 'test' in path:
        return 'test_asli'
    elif 'Validation' in path or 'validation' in path:
        return 'validation_asli'
    else:
        return 'unknown'

# ============================================================
# COPY / MOVE
# ============================================================
processed = 0
errors = 0
duplicates = 0
missing = 0

print('\nMemulai proses...\n')

for idx, row in df.iterrows():
    src_path = os.path.normpath(row['image_path'])
    filename = row['file_name']
    split_name = row['split']
    category = row['folder_category']

    # Tentukan asal file (train_asli, test_asli, validation_asli)
    origin = get_origin_from_path(src_path)

    # Destination directory dengan subfolder origin
    dst_dir = os.path.join(OUTPUT_ROOT, split_name, category, origin)
    os.makedirs(dst_dir, exist_ok=True)
    dst_path = os.path.join(dst_dir, filename)

    # Cek source exists
    if not os.path.exists(src_path):
        missing += 1
        print(f'[MISSING] {src_path}')
        continue

    # Cek duplikat di target (sebenarnya dengan subfolder ini jarang terjadi, tapi tetap)
    if os.path.exists(dst_path):
        duplicates += 1
        print(f'[DUPLICATE TARGET] {dst_path}')
        continue

    try:
        if COPY_MODE:
            shutil.copy2(src_path, dst_path)
        else:
            shutil.move(src_path, dst_path)
        processed += 1
        if processed % 10000 == 0:
            print(f'Processed: {processed:,}')
    except Exception as e:
        errors += 1
        print(f'[ERROR] {src_path}')
        print(e)

# ============================================================
# FINAL DIRECTORY COUNT
# ============================================================
print('\nMenghitung total file hasil split...\n')
final_count = 0
split_stats = {}

for split_name in ['Train', 'Validation', 'Test']:
    split_stats[split_name] = {}
    split_path = os.path.join(OUTPUT_ROOT, split_name)
    if not os.path.exists(split_path):
        continue
    for category in os.listdir(split_path):
        cat_path = os.path.join(split_path, category)
        if not os.path.isdir(cat_path):
            continue
        # Hitung semua file .png di dalam subfolder asal
        total_cat = 0
        for origin in os.listdir(cat_path):
            origin_path = os.path.join(cat_path, origin)
            if os.path.isdir(origin_path):
                png_count = len([f for f in os.listdir(origin_path) if f.lower().endswith('.png')])
                total_cat += png_count
        split_stats[split_name][category] = total_cat
        final_count += total_cat

# ============================================================
# FINAL SUMMARY
# ============================================================
print('=' * 60)
print('DATASET SPLIT SUMMARY')
print('=' * 60)
for split_name, categories in split_stats.items():
    subtotal = sum(categories.values())
    print(f'\n📁 {split_name} ({subtotal:,} files)')
    for category, count in sorted(categories.items()):
        print(f'   └── {category:12s}: {count:,}')

# ============================================================
# CSV VS DIRECTORY CHECK
# ============================================================
print('\n' + '=' * 60)
print('CSV vs DIRECTORY CHECK')
print('=' * 60)
print(f'\nCSV rows           : {len(df):,}')
print(f'Directory files    : {final_count:,}')
if len(df) == final_count:
    print('✅ MATCH')
else:
    print('❌ TIDAK MATCH (mungkin karena missing atau duplikat target)')

# ============================================================
# FINAL STATS
# ============================================================
print('\n' + '=' * 60)
print('PROCESS SUMMARY')
print('=' * 60)
print(f'Processed successfully : {processed:,}')
print(f'Duplicate skipped      : {duplicates:,}')
print(f'Missing source files   : {missing:,}')
print(f'Errors                 : {errors:,}')
print('\nOutput directory:')
print(OUTPUT_ROOT)
# Out:
# ============================================================
# MEMUAT CSV
# ============================================================
# Total rows CSV : 156,453
# Duplicate target filename (per split/category): 10,114
#
# ⚠ WARNING: Ada filename duplicate dalam split/category yang sama.
# Akan disimpan dengan subfolder berdasarkan asal untuk menghindari bentrok.
#
# ============================================================
# PROPORSI SPLIT
# ============================================================
# Train       : 109,517
# Validation  : 23,468
# Test        : 23,468
#
# Memulai proses...
#
# Processed: 10,000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[104], line 93
#      91 try:
#      92     if COPY_MODE:
# ---> 93         shutil.copy2(src_path, dst_path)
#      94     else:
#      95         shutil.move(src_path, dst_path)
#
# File c:\Users\Rainy\AppData\Local\Programs\Python\Python313\Lib\shutil.py:453, in copy2(src, dst, follow_symlinks)
#     451     flags |= _winapi.COPY_FILE_COPY_SYMLINK
#     452 try:
# --> 453     _winapi.CopyFile2(src_, dst_, flags)
#     454     return dst
#     455 except OSError as exc:
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd

from collections import defaultdict

# ============================================================
# CONFIG
# ============================================================

ROOT_DIR = r'Dataset/Gambo_Split'

CSV_PATH = 'master_dataset_final.csv'

# ============================================================
# LOAD CSV
# ============================================================

df = pd.read_csv(CSV_PATH)

print(f'Total row CSV: {len(df):,}')

# ============================================================
# SCAN DIRECTORY
# ============================================================

stats = defaultdict(lambda: defaultdict(int))

all_files = set()

duplicates = 0

for split in ['Train', 'Validation', 'Test']:

    split_path = os.path.join(ROOT_DIR, split)

    for root, dirs, files in os.walk(split_path):

        for file in files:

            if not file.lower().endswith('.png'):
                continue

            category = os.path.basename(root)

            full_path = os.path.normpath(
                os.path.join(root, file)
            )

            # count
            stats[split][category] += 1

            # duplicate leakage check
            relative_name = file

            if relative_name in all_files:
                duplicates += 1

            all_files.add(relative_name)

# ============================================================
# PRINT SPLIT SUMMARY
# ============================================================

print('\n' + '='*60)
print('DATASET SPLIT SUMMARY')
print('='*60)

total_scanned = 0

for split in ['Train', 'Validation', 'Test']:

    subtotal = sum(stats[split].values())

    total_scanned += subtotal

    print(f'\n📁 {split} ({subtotal:,} files)')

    for cat, count in sorted(stats[split].items()):

        print(f'   └── {cat:12s}: {count:,}')

# ============================================================
# CSV vs DIRECTORY
# ============================================================

print('\n' + '='*60)
print('CSV vs DIRECTORY CHECK')
print('='*60)

print(f'\nCSV rows           : {len(df):,}')
print(f'Directory files    : {total_scanned:,}')

if len(df) == total_scanned:
    print('✅ MATCH: CSV sinkron dengan directory')
else:
    print('❌ TIDAK MATCH')

# ============================================================
# MISSING FILE CHECK
# ============================================================

missing = 0

for _, row in df.iterrows():

    filename = row['file_name']

    found = False

    for split in ['Train', 'Validation', 'Test']:

        category = row['folder_category']

        path = os.path.join(
            ROOT_DIR,
            split,
            category,
            filename
        )

        if os.path.exists(path):
            found = True
            break

    if not found:
        missing += 1

print(f'\nMissing files : {missing:,}')

# ============================================================
# DUPLICATE LEAKAGE
# ============================================================

print(f'Duplicate leakage : {duplicates:,}')

if duplicates == 0:
    print('✅ Tidak ada data leakage')
else:
    print('❌ Ada duplicate antar split')

print('\n' + '='*60)
print('VERIFICATION DONE')
print('='*60)
# Out:
# Total row CSV: 156,453
#
# ============================================================
# DATASET SPLIT SUMMARY
# ============================================================
#
# 📁 Train (101,596 files)
#    └── Corrected   : 53,949
#    └── Normal      : 25,304
#    └── Reversal    : 22,343
#
# 📁 Validation (33,817 files)
#    └── Corrected   : 21,880
#    └── Normal      : 5,246
#    └── Reversal    : 6,691
#
# 📁 Test (25,875 files)
#    └── Corrected   : 11,961
#    └── Normal      : 5,440
#    └── Reversal    : 8,474
#
# ============================================================
# CSV vs DIRECTORY CHECK
# ============================================================
#
# CSV rows           : 156,453
# Directory files    : 161,288
# ❌ TIDAK MATCH
#
# Missing files : 0
# Duplicate leakage : 30,209
# ❌ Ada duplicate antar split
#
# ============================================================
# VERIFICATION DONE
# ============================================================

# %% [markdown]
# ### 5B. Hitung Class Weights untuk AI Engineer

# %%
from sklearn.utils.class_weight import compute_class_weight

train_final = df_final[df_final['split'] == 'Train']

# Binary
binary_classes = np.array([0, 1])
binary_weights = compute_class_weight('balanced', classes=binary_classes, y=train_final['target_class'].values)
binary_weight_dict = dict(zip(binary_classes.astype(int), binary_weights))

# Severity
severity_classes = np.sort(train_final['severity_score'].unique())
severity_weights = compute_class_weight('balanced', classes=severity_classes, y=train_final['severity_score'].values)
severity_weight_dict = dict(zip(severity_classes.astype(int), severity_weights))

print('=== CLASS WEIGHTS UNTUK AI ENGINEER ===')
print(f'\n\U0001f4ca Binary (target_class):')
for cls, w in binary_weight_dict.items():
    label = 'Normal' if cls == 0 else 'Disleksia'
    print(f'   Kelas {cls} ({label}): {w:.4f}')

print(f'\n\U0001f4ca Severity (severity_score):')
for cls, w in severity_weight_dict.items():
    print(f'   Skor {cls}: {w:.4f}')

print(f'\n\U0001f4a1 Gunakan dictionary ini sebagai parameter class_weight di model.fit()')

# %% [markdown]
# ### 5C. Validasi Visual Distribusi Split

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import os

sns.set_theme(style='whitegrid', palette='muted', font_scale=1.1)

fig = plt.figure(figsize=(18, 10))

# --- Panel 1: Pie chart proporsi split ---
ax1 = fig.add_subplot(2, 3, 1)
split_sizes = df_final['split'].value_counts().reindex(['Train', 'Validation', 'Test'])
colors_split = ['#3498db', '#f39c12', '#2ecc71']
ax1.pie(split_sizes, labels=[f'{s}\n({v:,})' for s, v in split_sizes.items()],
        colors=colors_split, autopct='%1.1f%%', startangle=90,
        textprops={'fontsize': 10, 'fontweight': 'bold'},
        wedgeprops={'edgecolor': 'white', 'linewidth': 2})
ax1.set_title('Proporsi Split', fontweight='bold', fontsize=12)

# --- Panel 2: Binary class per split ---
ax2 = fig.add_subplot(2, 3, 2)
binary_data = df_final.groupby(['split', 'target_class']).size().unstack(fill_value=0)
binary_data = binary_data.reindex(['Train', 'Validation', 'Test'])
binary_data.columns = ['Normal', 'Disleksia']
binary_data.plot(kind='bar', ax=ax2, color=['#2ecc71', '#e74c3c'], edgecolor='white')
ax2.set_title('Binary Class per Split', fontweight='bold', fontsize=12)
ax2.set_ylabel('Jumlah')
ax2.tick_params(axis='x', rotation=0)
ax2.legend(fontsize=9)

# --- Panel 3: Severity proporsi per split (normalized) ---
ax3 = fig.add_subplot(2, 3, 3)
for split in ['Train', 'Validation', 'Test']:
    subset = df_final[df_final['split'] == split]
    props = subset['severity_score'].value_counts().sort_index() / len(subset) * 100
    ax3.plot(props.index, props.values, marker='o', label=split, linewidth=2)
ax3.set_title('Proporsi Severity (%) per Split', fontweight='bold', fontsize=12)
ax3.set_xlabel('Severity Score')
ax3.set_ylabel('Proporsi (%)')
ax3.set_xticks(range(7))
ax3.legend()

# --- Panel 4-6: Sampel gambar acak dari tiap split ---
for idx, split in enumerate(['Train', 'Validation', 'Test']):
    ax = fig.add_subplot(2, 6, 7 + idx*2)
    subset = df_final[(df_final['split'] == split) & (df_final['target_class'] == 0)]
    sample = subset.sample(1, random_state=42).iloc[0]
    if os.path.exists(sample['image_path']):
        ax.imshow(mpimg.imread(sample['image_path']), cmap='gray')
    ax.set_title(f'{split}\nNormal', fontsize=9, fontweight='bold')
    ax.axis('off')
    
    ax_d = fig.add_subplot(2, 6, 8 + idx*2)
    subset_d = df_final[(df_final['split'] == split) & (df_final['target_class'] == 1)]
    sample_d = subset_d.sample(1, random_state=42).iloc[0]
    if os.path.exists(sample_d['image_path']):
        ax_d.imshow(mpimg.imread(sample_d['image_path']), cmap='gray')
    ax_d.set_title(f'{split}\nDisleksia', fontsize=9, fontweight='bold')
    ax_d.axis('off')

plt.suptitle('Validasi Visual Dataset Final (Tanpa Augmentasi Fisik)',
             fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# Cek konsistensi proporsi
print('\n=== PROPORSI SEVERITY PER SPLIT (%) ===')
for split in ['Train', 'Validation', 'Test']:
    subset = df_final[df_final['split'] == split]
    props = (subset['severity_score'].value_counts().sort_index() / len(subset) * 100).round(1)
    print(f'{split}: {dict(props)}')
print('\n\u2705 Jika ketiga garis di line chart berhimpitan, stratified split berhasil.')

# %% [markdown]
# ---
# # Tahap 6: Kesiapan Data untuk Pemodelan
#
# Tahap terakhir — memastikan dataset siap diserahkan ke AI Engineer.

# %% [markdown]
# ### 6A. Data Dictionary
#
# Definisi formal setiap kolom dalam `master_dataset_final.csv`:
#
# | Kolom | Tipe Data | Deskripsi | Nilai |
# |---|---|---|---|
# | `image_path` | String | Path relatif ke file gambar `.png` | Contoh: `Gambo/Train/Normal/Normal0001.png` |
# | `file_name` | String | Nama file gambar (tanpa path) | Contoh: `Normal0001.png` |
# | `split` | String | Pembagian dataset | `Train`, `Validation`, `Test` |
# | `folder_category` | String | Kategori kelas asal | `Normal`, `Corrected`, `Reversal` |
# | `severity_score` | Integer | Skor keparahan (normalisasi) | `0` = Normal, `1`–`6` = Ringan–Parah |
# | `target_class` | Integer | Label biner | `0` = Normal, `1` = Disleksia |
#
# ### Aturan untuk AI Engineer
#
# | Aturan | Penjelasan |
# |---|---|
# | **Input model** | Hanya `image_path` (baca piksel gambar) |
# | **Output utama** | `target_class` (klasifikasi biner) |
# | **Output sekunder** | `severity_score` (multi-class) |
# | **JANGAN sebagai fitur** | `severity_score`, `folder_category`, `file_name` — data leakage |
# | **Format gambar** | Grayscale, 28×28 piksel, `.png` |
# | **Horizontal Flip** | ❌ DILARANG — mengubah `b` menjadi `d` |

# %% [markdown]
# ### 6B. Rekomendasi Augmentasi untuk AI Engineer
#
# Data yang diserahkan adalah **data asli tanpa augmentasi fisik**. AI Engineer **sangat disarankan** menerapkan augmentasi **on-the-fly** saat training:
#
# ```python
# # Contoh menggunakan TensorFlow/Keras:
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# train_datagen = ImageDataGenerator(
#     rotation_range=10,        # Rotasi ±10°
#     zoom_range=0.1,           # Scaling 0.9×–1.1×
#     width_shift_range=0.05,   # Translasi horizontal kecil
#     height_shift_range=0.05,  # Translasi vertikal kecil
#     horizontal_flip=False,    # ❌ JANGAN — merusak Reversal
#     fill_mode='nearest',
#     rescale=1./255
# )
#
# # Validation & Test: HANYA rescale, tanpa augmentasi
# val_test_datagen = ImageDataGenerator(rescale=1./255)
# ```
#
# ### Keuntungan On-the-fly vs Offline
#
# | Aspek | On-the-fly (Rekomendasi) | Offline (Alternatif) |
# |---|---|---|
# | Variasi augmentasi | ∞ (setiap epoch berbeda) | Terbatas (4 copy tetap) |
# | Disk space | Hemat | +103K file tambahan |
# | Data leakage risk | Nol | Ada jika split salah urutan |
# | Distribution shift | Nol | Train ≠ Val/Test |
# | Fleksibilitas | AI Engineer bisa tune | Sudah fixed |
#
# > 📦 Jika AI Engineer tetap ingin menggunakan augmentasi offline, file `Dyslexia_OfflineAugmentation.ipynb` tersedia sebagai alternatif.

# %% [markdown]
# ### 6C. Validasi Akhir

# %%
df_check = pd.read_csv(CSV_OUTPUT)

print('=== VALIDASI AKHIR: master_dataset_final.csv ===')
print(f'Total baris: {len(df_check):,}')
print(f'Kolom: {list(df_check.columns)}')

# Cek proporsi
total = len(df_check)
print(f'\n=== PROPORSI SPLIT ===')
for split in ['Train', 'Validation', 'Test']:
    n = len(df_check[df_check['split'] == split])
    print(f'{split:12s}: {n:>8,} gambar ({n/total*100:5.1f}%)')

# Cek data leakage
val_paths = set(df_check[df_check['split'] == 'Validation']['image_path'])
train_paths = set(df_check[df_check['split'] == 'Train']['image_path'])
test_paths = set(df_check[df_check['split'] == 'Test']['image_path'])

print(f'\n=== CEK DATA LEAKAGE ===')
print(f'Train \u2229 Validation: {len(train_paths & val_paths)}')
print(f'Train \u2229 Test      : {len(train_paths & test_paths)}')
print(f'Validation \u2229 Test : {len(val_paths & test_paths)}')

if len(train_paths & val_paths) == 0 and len(train_paths & test_paths) == 0:
    print('\n\u2705 AMAN — Nol data leakage di semua split.')
else:
    print('\n\u26a0\ufe0f PERINGATAN — Ada overlap!')

print(f'\n\u2705 Dataset siap untuk handover ke AI Engineer.')

# %% [markdown]
# ### Kesimpulan Pipeline Data Scientist
#
# | Tahap | Output | Status |
# |---|---|---|
# | 1. Assessing Data | Audit distribusi, resolusi, anomali | ✅ |
# | 2. Physical Renaming | Normalisasi skala severity 1–6 | ✅ (Opsional) |
# | 3. Cleaning Data | `master_dataset_dyslexia.csv` (180.726 baris) | ✅ |
# | 4. EDA + Explanatory | Visualisasi distribusi, heatmap, jawaban bisnis | ✅ |
# | 5. Stratified Split | Train/Validation/Test (stratified by severity) | ✅ |
# | 6. Kesiapan Data | Data Dictionary + class weights + rekomendasi | ✅ |
#
# **File output untuk AI Engineer:**
#
# | File | Deskripsi |
# |---|---|
# | `master_dataset_final.csv` | Dataset bersih dengan 3 split, tanpa augmentasi fisik |
# | `Dyslexia_OfflineAugmentation.ipynb` | Alternatif dengan augmentasi offline (skor 2–5 ×5) |
#
# **Handover ke AI Engineer:**
# 1. Gunakan `master_dataset_final.csv` sebagai *single source of truth*
# 2. Terapkan augmentasi **on-the-fly** (contoh kode di sel 6B)
# 3. Gunakan `class_weight` dari sel 5B
# 4. Evaluasi dengan **F1-Score** dan **Recall**
# 5. **JANGAN** gunakan Horizontal Flip

# %% [markdown]
# ---
# # Tahap 7: Feature Engineering (Side Quest)
#
# Tahap ini mengekstrak **fitur turunan matematis** dari setiap gambar 28×28 piksel.
# Alih-alih hanya menyerahkan matriks piksel mentah kepada AI Engineer, kita menghitung variabel-variabel tabular baru yang merepresentasikan **karakteristik goresan tulisan** secara numerik.
#
# Fitur ini sangat berguna jika AI Engineer ingin membangun **Multi-Input Model** (Functional API) yang menggabungkan CNN (untuk gambar) dengan Dense Layer (untuk fitur tabular) secara bersamaan.
#
# ### Fitur yang Diekstrak:
# | Fitur | Deskripsi |
# |---|---|
# | `ink_density` | Persentase piksel hitam (tinta) terhadap total area gambar (784 piksel). Tulisan yang banyak dicoreng akan memiliki kepadatan tinta lebih tinggi. |
# | `center_of_mass_x` | Posisi titik tengah goresan pada sumbu horizontal (0-27). Huruf yang miring atau asimetris akan memiliki centroid yang melenceng. |
# | `center_of_mass_y` | Posisi titik tengah goresan pada sumbu vertikal (0-27). |
# | `bounding_box_ratio` | Rasio tinggi/lebar area goresan setelah whitespace dipangkas. Huruf yang direvisi berulang kali cenderung melebar (rasio < 1). |
# | `stroke_transitions` | Rata-rata jumlah transisi warna putih↔hitam per baris horizontal. Goresan berantakan memiliki transisi lebih tinggi. |

# %%
import pandas as pd
import numpy as np
from PIL import Image
import os

# === Konfigurasi ===
CSV_INPUT = 'master_dataset_final.csv'  # Output dari Tahap 5
CSV_OUTPUT = 'master_dataset_final_featured.csv'
IMG_SIZE = 28
THRESHOLD = 128  # Piksel < 128 = hitam (goresan), >= 128 = putih (latar)

df = pd.read_csv(CSV_INPUT)
print(f'Memuat {len(df):,} baris dari {CSV_INPUT}')
print(f'Kolom awal: {df.columns.tolist()}')

# %%
def extract_features(image_path):
    """
    Mengekstrak 5 fitur turunan dari satu gambar grayscale 28x28.
    Returns dict of features, atau dict berisi NaN jika gambar error.
    """
    try:
        img = Image.open(image_path).convert('L').resize((28, 28))
        pixels = np.array(img, dtype=np.float64)
        binary = (pixels > THRESHOLD).astype(np.float64)  # 1 = tinta, 0 = latar
        
        # 1. Ink Density (kepadatan tinta)
        total_pixels = IMG_SIZE * IMG_SIZE
        ink_density = np.sum(binary) / total_pixels
        
        # 2 & 3. Center of Mass (titik tengah goresan)
        ink_sum = np.sum(binary)
        if ink_sum > 0:
            y_coords, x_coords = np.where(binary == 1)
            center_x = np.mean(x_coords)
            center_y = np.mean(y_coords)
        else:
            center_x, center_y = IMG_SIZE / 2, IMG_SIZE / 2
        
        # 4. Bounding Box Ratio (rasio tinggi/lebar area goresan)
        if ink_sum > 0:
            rows_with_ink = np.any(binary, axis=1)
            cols_with_ink = np.any(binary, axis=0)
            height = np.sum(rows_with_ink)
            width = np.sum(cols_with_ink)
            bbox_ratio = height / max(width, 1)
        else:
            bbox_ratio = 1.0
        
        # 5. Stroke Transitions (rata-rata transisi putih-hitam per baris)
        transitions = 0
        for row in binary:
            diffs = np.abs(np.diff(row))
            transitions += np.sum(diffs)
        stroke_transitions = transitions / IMG_SIZE
        
        return {
            'ink_density': round(ink_density, 6),
            'center_of_mass_x': round(center_x, 4),
            'center_of_mass_y': round(center_y, 4),
            'bounding_box_ratio': round(bbox_ratio, 4),
            'stroke_transitions': round(stroke_transitions, 4)
        }
    except Exception as e:
        return {
            'ink_density': np.nan,
            'center_of_mass_x': np.nan,
            'center_of_mass_y': np.nan,
            'bounding_box_ratio': np.nan,
            'stroke_transitions': np.nan
        }

print('Fungsi extract_features() siap digunakan.')

# %%
# === Eksekusi Feature Extraction ===
features_list = []
errors = 0

for i, row in df.iterrows():
    img_path = row['image_path']
    features = extract_features(img_path)
    features_list.append(features)
    
    if np.isnan(features['ink_density']):
        errors += 1
    
    if (i + 1) % 20000 == 0:
        print(f'  Processed {i+1:,}/{len(df):,}...')

# Gabungkan fitur ke DataFrame utama
df_features = pd.DataFrame(features_list)
df_final = pd.concat([df.reset_index(drop=True), df_features], axis=1)

print(f'\n=== Hasil Feature Engineering ===')
print(f'Kolom baru: {df_features.columns.tolist()}')
print(f'Total baris: {len(df_final):,} | Error: {errors}')
print(f'Shape akhir: {df_final.shape}')
df_final.head()

# %% [markdown]
# ### 7A. Validasi Statistik Fitur Baru
#
# Memvalidasi bahwa fitur-fitur yang diekstrak memiliki **distribusi yang bermakna** dan berbeda antara kelas Normal vs Disleksia.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')

feature_cols = ['ink_density', 'center_of_mass_x', 'center_of_mass_y', 
                'bounding_box_ratio', 'stroke_transitions']

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle('Distribusi Fitur Turunan: Normal vs Disleksia', fontsize=14, fontweight='bold')

for idx, feat in enumerate(feature_cols):
    ax = axes[idx // 3][idx % 3]
    for label, color, name in [(0, '#2ECC71', 'Normal'), (1, '#E74C3C', 'Disleksia')]:
        subset = df_final[df_final['target_class'] == label][feat].dropna()
        ax.hist(subset, bins=40, alpha=0.6, color=color, label=name, density=True)
    ax.set_title(feat, fontweight='bold')
    ax.legend()

# Kosongkan subplot ke-6 yang tidak terpakai
axes[1][2].axis('off')
plt.tight_layout()
plt.savefig('../assets/feature_engineering_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
print('Grafik distribusi fitur tersimpan di assets/feature_engineering_distribution.png')

# %%
# === Ringkasan Statistik per Kelas ===
print('=== Rata-rata Fitur per Kelas ===')
summary = df_final.groupby('target_class')[feature_cols].mean()
summary.index = ['Normal (0)', 'Disleksia (1)']
print(summary.round(4).to_string())

print('\n=== Selisih Absolut (Disleksia - Normal) ===')
diff = summary.loc['Disleksia (1)'] - summary.loc['Normal (0)']
print(diff.round(4).to_string())
print('\nFitur dengan selisih terbesar menunjukkan potensi diskriminatif tertinggi untuk model AI.')

# %% [markdown]
# ### 7B. Simpan Dataset Final + Fitur Turunan

# %%
# === Simpan CSV dengan kolom fitur baru ===
df_final.to_csv(CSV_OUTPUT, index=False)
print(f'Dataset tersimpan: {CSV_OUTPUT}')
print(f'Kolom final: {df_final.columns.tolist()}')
print(f'Total baris: {len(df_final):,}')
print(f'\nData Dictionary Fitur Baru:')
print('  ink_density        : Kepadatan tinta (0.0-1.0). Semakin tinggi = semakin banyak coretan.')
print('  center_of_mass_x   : Titik tengah goresan sumbu-X (0-27). Menyimpang = asimetris.')
print('  center_of_mass_y   : Titik tengah goresan sumbu-Y (0-27).')
print('  bounding_box_ratio : Rasio tinggi/lebar bounding box goresan. <1 = melebar, >1 = memanjang.')
print('  stroke_transitions : Rata-rata transisi warna per baris. Tinggi = goresan berantakan.')

# %% [markdown]
# ---
# ## 📦 Kompresi Dataset
# Kompilasi folder `Dataset/Gambo` menjadi `.zip` agar mudah dibagikan kepada kolega.

# %%
import shutil
import os

folder_to_zip = 'Dataset/Gambo'
output_zip = 'Dataset_Gambo_Final_NoAugmentation'

if os.path.exists(folder_to_zip):
    print(f"Mengompresi {folder_to_zip} menjadi {output_zip}.zip...")
    shutil.make_archive(output_zip, 'zip', folder_to_zip)
    print("✅ Selesai! File zip berhasil dibuat di direktori saat ini.")
else:
    print(f"❌ Folder {folder_to_zip} tidak ditemukan!")
